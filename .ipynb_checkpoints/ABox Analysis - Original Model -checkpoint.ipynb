# %%
from os import walk

dirpath = "ABox";
filenames = next(walk(dirpath), (None, None, []))[2]  # [] if no file
print(filenames)
# Out:
# ['C_B307_Brick.ttl', 'C_B307_DigitalBuilding.ttl', 'C_B307_Haystack.ttl', 'C_B307_RECore.ttl']

# %%
from rdflib import Graph as RDFGraph
from rdflib.extras.external_graph_libs import rdflib_to_networkx_digraph

# loadn RDF Graph
dic = {}
for filename in filenames:
    print(filename)
    path = dirpath + "/" + filename
    g = RDFGraph()
    g.parse(path)
    print("rdflib Graph loaded successfully with {} triples".format(len(g)))
    G = rdflib_to_networkx_digraph(g)
    print("networkx Graph loaded successfully with length {}".format(len(G)))
    dic.update({str(filename):G})
# print (dic)
# Out:
# C_B307_Brick.ttl
# rdflib Graph loaded successfully with 751 triples
# networkx Graph loaded successfully with length 489
# C_B307_DigitalBuilding.ttl
# rdflib Graph loaded successfully with 819 triples
# networkx Graph loaded successfully with length 469
# C_B307_Haystack.ttl
# rdflib Graph loaded successfully with 800 triples
# networkx Graph loaded successfully with length 471
# C_B307_RECore.ttl
# rdflib Graph loaded successfully with 1008 triples
# networkx Graph loaded successfully with length 483

# %%
# show complete node
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
number_of_nodes = {}
for k, v in dic.items():
    v = v.number_of_nodes()
    number_of_nodes.update({k:v})

number_of_nodes_df = pd.DataFrame(data = number_of_nodes,index=[0])
number_of_nodes_df.head(10)
# Out:
#    C_B307_Brick.ttl  C_B307_DigitalBuilding.ttl  C_B307_Haystack.ttl  \
# 0               489                         469                  471
#
#    C_B307_RECore.ttl
# 0                483

# %%
number_of_edges = {}
for k, v in dic.items():
    v = v.number_of_edges()
    number_of_edges.update ({k:v})

number_of_edges_df = pd.DataFrame(data = number_of_edges,index=[0])
number_of_edges_df.head(10)
# Out:
#    C_B307_Brick.ttl  C_B307_DigitalBuilding.ttl  C_B307_Haystack.ttl  \
# 0               751                         819                  800
#
#    C_B307_RECore.ttl
# 0                782

# %%
prefix_brick = "http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#"
prefix_haystack = "http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#"
prefix_recore = "http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#"
prefix_digitalbuilding = "http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#"
prefix_test = "dch:org/csiro/site/Clayton/building/307_R_L_Sandland#"
prefix = [prefix_brick, prefix_haystack, prefix_recore, prefix_digitalbuilding]

# %% [markdown]
# ### Dan's Paper (degree and class hierarchy/depth)

# %%
import networkx as nx

dan_summary_brick_df = pd.DataFrame()
dan_summary_haystack_df = pd.DataFrame()
dan_summary_recore_df = pd.DataFrame()
dan_summary_digitalbuilding_df = pd.DataFrame()

# %%
# number of degree
for k, v in dic.items():
    number_of_degree_df = pd.DataFrame(data = v.degree(), 
                                           columns = ["node", "number_of_degree"])
    # filter
    if k == "C_B307_Brick.ttl":
        number_of_degree_df = number_of_degree_df[number_of_degree_df['node'].str.startswith(prefix_brick)]
        dan_summary_brick_df = number_of_degree_df
    if k == "C_B307_Haystack.ttl":
        number_of_degree_df = number_of_degree_df[number_of_degree_df['node'].str.startswith(prefix_haystack)]
        dan_summary_haystack_df = number_of_degree_df
    if k == "C_B307_RECore.ttl":
        number_of_degree_df = number_of_degree_df[number_of_degree_df['node'].str.startswith(prefix_recore)]
        dan_summary_recore_df = number_of_degree_df
    if k == "C_B307_DigitalBuilding.ttl":
        number_of_degree_df = number_of_degree_df[number_of_degree_df['node'].str.startswith(prefix_digitalbuilding)]
        dan_summary_digitalbuilding_df = number_of_degree_df
#     if k == "C_B307_test.ttl":
#         numbr_of_degree_df = numbr_of_degree_df[numbr_of_degree_df['node'].str.startswith(prefix_test)]
    
    # sort
    number_of_degree_df = number_of_degree_df.sort_values("number_of_degree", ascending = False)
    # reset index
    number_of_degree_df = number_of_degree_df.reset_index(drop=True)
    
    # print
    print ("file:", k)
    print("data points", len(number_of_degree_df.index))
    print (number_of_degree_df.head(5))
    print ("====================================================================================================")
# Out:
# file: C_B307_Brick.ttl
# data points 226
#                                                                                node  \
# 0  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Chiller1
# 1   http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Boiler1
# 2        http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#B1
# 3        http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#F1
# 4        http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#G1
#
#    number_of_degree
# 0                21
# 1                21
# 2                16
# 3                15
# 4                14
# ====================================================================================================
# file: C_B307_DigitalBuilding.ttl
# data points 226
#                                                                                                    node  \
# 0    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground
# 1    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1
# 2  http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Basement
# 3  http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Chiller1
# 4   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Boiler1
#
#    number_of_degree
# 0                30
# 1                28
# 2                20
# 3                20
# 4                20
# ====================================================================================================
# file: C_B307_Haystack.ttl
# data points 226
#                                                                                          node  \
# 0  http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Building307
# 1       http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Ground
# 2       http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Level1
# 3     http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Basement
# 4           http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#B1
#
#    number_of_degree
# 0                30
# 1                30
# 2                28
# 3                20
# 4                16
# ====================================================================================================
# file: C_B307_RECore.ttl
# data points 226
#                                                                                          node  \
# 0         http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#Boiler1
# 1        http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#Chiller1
# 2  http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_HHWCoil
# 3              http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#B1
# 4              http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#F1
#
#    number_of_degree
# 0                20
# 1                20
# 2                17
# 3                16
# 4                15
# ====================================================================================================

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x1 = dan_summary_brick_df.number_of_degree
x2 = dan_summary_haystack_df.number_of_degree
x3 = dan_summary_recore_df.number_of_degree
x4 = dan_summary_digitalbuilding_df.number_of_degree
plt.boxplot ([x1,x2,x3,x4])
plt.xticks([1,2,3,4], ['Brick','Haystack','RECore','DigitalBuilding'])
plt.title ("Number of Degrees (Original Model)")
plt.savefig('Number of Degrees-Original.jpg', bbox_inches='tight', dpi=500)

# %%
# start from root to each node, calculate the depth for each node
from rdflib import URIRef
# class hierarchy/depth
for k, v in dic.items():
    
    # filter
    if k == "C_B307_Brick.ttl":        
        
        root = URIRef('http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AHU_F1')
        
        data = {}
        
        for i,j in v.nodes(data=True):
                
            paths = nx.all_simple_paths(v, source = root, target = i)
            
            if(len(list(paths)) == 0):
                depth = 0
                # data.update({i:depth})
            else:
                depth = len(max(nx.all_simple_paths(v, source = root, target = i), key=lambda x: len(x)))-1
                data.update({i:depth})
            
        class_hierarchy_df = pd.DataFrame.from_dict(data = data, orient='index', columns = ["class_hierarchy"])
        class_hierarchy_df.index.rename('node', inplace=True)
        class_hierarchy_df = class_hierarchy_df.reset_index()
        # filter
        class_hierarchy_df = class_hierarchy_df[class_hierarchy_df['node'].str.startswith(prefix_brick)]
        # sort
        class_hierarchy_df = class_hierarchy_df.sort_values("class_hierarchy", ascending = False)
        # reset index
        class_hierarchy_df = class_hierarchy_df.reset_index(drop=True)
        # merge
        dan_summary_brick_df = class_hierarchy_df

    
    if k == "C_B307_Haystack.ttl":        

        root = URIRef('http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#AHU_F1')

        data = {}

        for i,j in v.nodes(data=True):

            paths = nx.all_simple_paths(v, source = root, target = i)

            if(len(list(paths)) == 0):
                depth = 0
                # data.update({i:depth})
            else:
                depth = len(max(nx.all_simple_paths(v, source = root, target = i), key=lambda x: len(x)))-1
                data.update({i:depth})

        class_hierarchy_df = pd.DataFrame.from_dict(data = data, orient='index', columns = ["class_hierarchy"])
        class_hierarchy_df.index.rename('node', inplace=True)
        class_hierarchy_df = class_hierarchy_df.reset_index()
        # filter
        class_hierarchy_df = class_hierarchy_df[class_hierarchy_df['node'].str.startswith(prefix_haystack)]
        # sort
        class_hierarchy_df = class_hierarchy_df.sort_values("class_hierarchy", ascending = False)
        # reset index
        class_hierarchy_df = class_hierarchy_df.reset_index(drop=True)
        # merge
        dan_summary_haystack_df = class_hierarchy_df
    
    if k == "C_B307_RECore.ttl":        

        root = URIRef('http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_F1')

        data = {}

        for i,j in v.nodes(data=True):

            paths = nx.all_simple_paths(v, source = root, target = i)
            
            if(len(list(paths)) == 0):
                depth = 0
                # data.update({i:depth})
            else:
                depth = len(max(nx.all_simple_paths(v, source = root, target = i), key=lambda x: len(x)))-1
                data.update({i:depth})

        class_hierarchy_df = pd.DataFrame.from_dict(data = data, orient='index', columns = ["class_hierarchy"])
        class_hierarchy_df.index.rename('node', inplace=True)
        class_hierarchy_df = class_hierarchy_df.reset_index()
        # filter
        class_hierarchy_df = class_hierarchy_df[class_hierarchy_df['node'].str.startswith(prefix_recore)]
        # sort
        class_hierarchy_df = class_hierarchy_df.sort_values("class_hierarchy", ascending = False)
        # reset index
        class_hierarchy_df = class_hierarchy_df.reset_index(drop=True)
        # merge
        dan_summary_recore_df = class_hierarchy_df
        
    if k == "C_B307_DigitalBuilding.ttl":        

        root = URIRef('http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AHU_F1')

        data = {}

        for i,j in v.nodes(data=True):

            paths = nx.all_simple_paths(v, source = root, target = i)
            
            if(len(list(paths)) == 0):
                depth = 0
                # data.update({i:depth})
            else:
                depth = len(max(nx.all_simple_paths(v, source = root, target = i), key=lambda x: len(x)))-1
                data.update({i:depth})

        class_hierarchy_df = pd.DataFrame.from_dict(data = data, orient='index', columns = ["class_hierarchy"])
        class_hierarchy_df.index.rename('node', inplace=True)
        class_hierarchy_df = class_hierarchy_df.reset_index()
        # filter
        class_hierarchy_df = class_hierarchy_df[class_hierarchy_df['node'].str.startswith(prefix_digitalbuilding)]
        # sort
        class_hierarchy_df = class_hierarchy_df.sort_values("class_hierarchy", ascending = False)
        # reset index
        class_hierarchy_df = class_hierarchy_df.reset_index(drop=True)
        # merge
        dan_summary_digitalbuilding_df = class_hierarchy_df
    
    # print
    print ("file:", k)
    print("data points", len(class_hierarchy_df.index))
    print (class_hierarchy_df.head(10))
    print ("====================================================================================================")
# Out:
# file: C_B307_Brick.ttl
# data points 28
#                                                                                      node  \
# 0  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Basement_B.116
# 1        http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Chiller1
# 2         http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Boiler1
# 3   http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1_1.117a
# 4    http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1_1.114
# 5    http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1_1.100
# 6        http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Basement
# 7    http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1_1.112
# 8  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AHU_F1_CHWCoil
# 9          http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1
#
#    class_hierarchy
# 0                4
# 1                3
# 2                3
# 3                2
# 4                2
# 5                2
# 6                2
# 7                2
# 8                2
# 9                2
# ====================================================================================================
# file: C_B307_DigitalBuilding.ttl
# data points 84
#                                                                                                         node  \
# 0   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.121
# 1  http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.117a
# 2   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.100
# 3   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.108
# 4   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.111
# 5   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.107
# 6   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.111
# 7   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.115
# 8   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.118
# 9   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.114
#
#    class_hierarchy
# 0                3
# 1                3
# 2                3
# 3                3
# 4                3
# 5                3
# 6                3
# 7                3
# 8                3
# 9                3
# ====================================================================================================
# file: C_B307_Haystack.ttl
# data points 1
#                                                                                          node  \
# 0  http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Building307
#
#    class_hierarchy
# 0                1
# ====================================================================================================
# file: C_B307_RECore.ttl
# data points 35
#                                                                                                node  \
# 0              http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#Chiller1
# 1        http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_CHWCoil
# 2   http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_ReturnDamper
# 3               http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#Boiler1
# 4         http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_ClgVlv
# 5         http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_Filter
# 6  http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_OutsideDamper
# 7      http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_SupplyFan
# 8         http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_HtgVlv
# 9        http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_HHWCoil
#
#    class_hierarchy
# 0                7
# 1                6
# 2                5
# 3                5
# 4                5
# 5                5
# 6                5
# 7                5
# 8                4
# 9                4
# ====================================================================================================

# %%
dan_summary_brick_df
# Out:
#                                                                                             node  \
# 0         http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Basement_B.116
# 1               http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Chiller1
# 2                http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Boiler1
# 3          http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1_1.117a
# 4           http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1_1.114
# 5           http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1_1.100
# 6               http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Basement
# 7           http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1_1.112
# 8         http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AHU_F1_CHWCoil
# 9                 http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1
# 10          http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1_1.103
# 11                http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Ground
# 12        http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AHU_F1_HHWCoil
# 13          http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1_1.111
# 14          http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1_1.117
# 15          http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1_1.115
# 16          http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1_1.102
# 17          http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1_1.116
# 18          http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1_1.113
# 19          http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1_1.101
# 20           http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Building307
# 21         http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AHU_F1_Filter
# 22   http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AHU_F1_ReturnDamper
# 23         http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AHU_F1_ClgVlv
# 24         http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AHU_F1_HtgVlv
# 25  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AHU_F1_OutsideDamper
# 26                    http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#F1
# 27      http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AHU_F1_SupplyFan
#
#     class_hierarchy
# 0                 4
# 1                 3
# 2                 3
# 3                 2
# 4                 2
# 5                 2
# 6                 2
# 7                 2
# 8                 2
# 9                 2
# 10                2
# 11                2
# 12                2
# 13                2
# 14                2
# 15                2
# 16                2
# 17                2
# 18                2
# 19                2
# 20                1
# 21                1
# 22                1
# 23                1
# 24                1
# 25                1
# 26                1
# 27                1

# %%
x1 = dan_summary_brick_df.class_hierarchy
x2 = dan_summary_haystack_df.class_hierarchy
x3 = dan_summary_recore_df.class_hierarchy
x4 = dan_summary_digitalbuilding_df.class_hierarchy
plt.boxplot ([x1,x2,x3,x4])
plt.xticks([1,2,3,4], ['Brick','Haystack','RECore','DigitalBuilding'])
plt.title ("Class Hierarchy (Original Model)")
plt.savefig('Class Hierarchy-Original.jpg', bbox_inches='tight', dpi=500)

# %%
# testbed
from rdflib import URIRef
# class hierarchy
for k, v in dic.items():
    
    # filter
    if k == "C_B307_Brick.ttl":
        
        a = URIRef('http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Building307')
        
        print(v.has_node(a))
        
        
        nx.shortest_path_length(v,a)
        
        path = dict(nx.all_pairs_shortest_path(v))
        
        aa = {}
        for key, value in path[URIRef('http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Building307')].items():
            aa.update({key:len([item for item in value if item])-1})
        print(aa)
            
        numbr_of_degree_df = pd.DataFrame.from_dict(data = aa, orient='index', columns = ["numbr_of_degree"])
    
        numbr_of_degree_df.index.rename('node', inplace=True)
        numbr_of_degree_df = numbr_of_degree_df.reset_index()
    
        print (numbr_of_degree_df)
# Out:
# True
# {rdflib.term.URIRef('http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Building307'): 0, rdflib.term.URIRef('https://brickschema.org/schema/Brick#Building'): 1, rdflib.term.URIRef('http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1'): 1, rdflib.term.Literal('Building307'): 1, rdflib.term.URIRef('http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Basement'): 1, rdflib.term.URIRef('http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Ground'): 1, rdflib.term.Literal('Level1'): 2, rdflib.term.URIRef('https://brickschema.org/schema/Brick#Floor'): 2, rdflib.term.Literal('Basement'): 2, rdflib.term.URIRef('https://brickschema.org/schema/Brick#Basement'): 2, rdflib.term.Literal('Ground'): 2}
#                                                                                    node  \
# 0   http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Building307
# 1                                         https://brickschema.org/schema/Brick#Building
# 2        http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1
# 3                                                                           Building307
# 4      http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Basement
# 5        http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Ground
# 6                                                                                Level1
# 7                                            https://brickschema.org/schema/Brick#Floor
# 8                                                                              Basement
# 9                                         https://brickschema.org/schema/Brick#Basement
# 10                                                                               Ground
#
#     numbr_of_degree
# 0                 0
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# 5                 1
# 6                 2
# 7                 2
# 8                 2
# 9                 2
# 10                2

# %%
# alternative way to calculate
from rdflib import URIRef
# class hierarchy
for k, v in dic.items():
    
    # filter
    if k == "C_B307_Brick.ttl":
        
        path = dict(nx.all_pairs_shortest_path(v))
        
        aa = {}
        for key, value in path[URIRef('http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Building307')].items():
            aa.update({key:len([item for item in value if item])-1})
        print(aa)
            
        numbr_of_degree_df = pd.DataFrame.from_dict(data = aa, orient='index', columns = ["numbr_of_degree"])
    
        numbr_of_degree_df.index.rename('node', inplace=True)
        numbr_of_degree_df = numbr_of_degree_df.reset_index()
    
        print (numbr_of_degree_df)
# Out:
# {rdflib.term.URIRef('http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Building307'): 0, rdflib.term.URIRef('https://brickschema.org/schema/Brick#Building'): 1, rdflib.term.URIRef('http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1'): 1, rdflib.term.Literal('Building307'): 1, rdflib.term.URIRef('http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Basement'): 1, rdflib.term.URIRef('http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Ground'): 1, rdflib.term.Literal('Level1'): 2, rdflib.term.URIRef('https://brickschema.org/schema/Brick#Floor'): 2, rdflib.term.Literal('Basement'): 2, rdflib.term.URIRef('https://brickschema.org/schema/Brick#Basement'): 2, rdflib.term.Literal('Ground'): 2}
#                                                                                    node  \
# 0   http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Building307
# 1                                         https://brickschema.org/schema/Brick#Building
# 2        http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1
# 3                                                                           Building307
# 4      http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Basement
# 5        http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Ground
# 6                                                                                Level1
# 7                                            https://brickschema.org/schema/Brick#Floor
# 8                                                                              Basement
# 9                                         https://brickschema.org/schema/Brick#Basement
# 10                                                                               Ground
#
#     numbr_of_degree
# 0                 0
# 1                 1
# 2                 1
# 3                 1
# 4                 1
# 5                 1
# 6                 2
# 7                 2
# 8                 2
# 9                 2
# 10                2

# %% [markdown]
# ### Centrality Analysis

# %% [markdown]
# ### 1. Heuristic (simple) centrality: Degree centrality (local importance)

# %%
import networkx as nx

centrality_summary_brick_df = pd.DataFrame()
centrality_summary_haystack_df = pd.DataFrame()
centrality_summary_recore_df = pd.DataFrame()
centrality_summary_digitalbuilding_df = pd.DataFrame()

# %%
# in-degree centrality
for k, v in dic.items():
    in_degree_centrality_df = pd.DataFrame(data = nx.in_degree_centrality(v).items(), 
                                           columns = ["node", "in_degree_centrality"])
#     print (in_degree_centrality_df.head(10))
    # filter
    if k == "C_B307_Brick.ttl":
        in_degree_centrality_df = in_degree_centrality_df[in_degree_centrality_df['node'].str.startswith(prefix_brick)]
        centrality_summary_brick_df = in_degree_centrality_df
    if k == "C_B307_Haystack.ttl":
        in_degree_centrality_df = in_degree_centrality_df[in_degree_centrality_df['node'].str.startswith(prefix_haystack)]
        centrality_summary_haystack_df = in_degree_centrality_df
    if k == "C_B307_RECore.ttl":
        in_degree_centrality_df = in_degree_centrality_df[in_degree_centrality_df['node'].str.startswith(prefix_recore)]
        centrality_summary_recore_df = in_degree_centrality_df
    if k == "C_B307_DigitalBuilding.ttl":
        in_degree_centrality_df = in_degree_centrality_df[in_degree_centrality_df['node'].str.startswith(prefix_digitalbuilding)]
        centrality_summary_digitalbuilding_df = in_degree_centrality_df
    
    # sort
    in_degree_centrality_df = in_degree_centrality_df.sort_values("in_degree_centrality", ascending = False)
    
    # print
    print (k)
    print (in_degree_centrality_df.head(10))
    print ("==================================================")
# Out:
# C_B307_Brick.ttl
#                                                                                          node  \
# 56            http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Boiler1
# 17           http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Chiller1
# 168       http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Building307
# 249     http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AC_G3_HHWCoil
# 251      http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1_1.110
# 112    http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#FCU_B2_HHWCoil
# 102  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AHU_B1_SupplyFan
# 100      http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1_1.109
# 97     http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#FCU_G7_HHWCoil
# 266     http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AC_G6_HHWCoil
#
#      in_degree_centrality
# 56               0.036885
# 17               0.036885
# 168              0.010246
# 249              0.004098
# 251              0.004098
# 112              0.004098
# 102              0.004098
# 100              0.004098
# 97               0.004098
# 266              0.004098
# ==================================================
# C_B307_DigitalBuilding.ttl
#                                                                                                            node  \
# 54          http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Boiler1
# 19         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Chiller1
# 42      http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Building307
# 18   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_B2_CHWCoil
# 246    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.104
# 138    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.110
# 126    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.124
# 71     http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.104
# 165    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.112
# 169    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.109
#
#      in_degree_centrality
# 54               0.038462
# 19               0.038462
# 42               0.010684
# 18               0.006410
# 246              0.006410
# 138              0.006410
# 126              0.006410
# 71               0.006410
# 165              0.006410
# 169              0.006410
# ==================================================
# C_B307_Haystack.ttl
#                                                                                            node  \
# 56   http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Building307
# 22        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Ground
# 28        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Level1
# 37      http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Basement
# 104           http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#B1
# 148           http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#F1
# 91            http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#G1
# 3             http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#G2
# 281           http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#F2
# 43        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#AHU_F2
#
#      in_degree_centrality
# 56               0.059574
# 22               0.057447
# 28               0.053191
# 37               0.036170
# 104              0.027660
# 148              0.023404
# 91               0.023404
# 3                0.021277
# 281              0.017021
# 43               0.017021
# ==================================================
# C_B307_RECore.ttl
#                                                                                                  node  \
# 80               http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#Chiller1
# 25                http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#Boiler1
# 3          http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_CHWCoil
# 67         http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_HHWCoil
# 134      http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_SupplyFan
# 270         http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_Filter
# 40            http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#Building307
# 151  http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_OutsideDamper
# 104   http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_ReturnDamper
# 96          http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_ClgVlv
#
#      in_degree_centrality
# 80               0.037344
# 25               0.037344
# 3                0.012448
# 67               0.012448
# 134              0.010373
# 270              0.010373
# 40               0.010373
# 151              0.010373
# 104              0.010373
# 96               0.010373
# ==================================================

# %%
# out-degree centrality
for k, v in dic.items():
    out_degree_centrality_df = pd.DataFrame(data = nx.out_degree_centrality(v).items(), 
                                           columns = ["node", "out_degree_centrality"])
    # filter
    if k == "C_B307_Brick.ttl":
        out_degree_centrality_df = out_degree_centrality_df[out_degree_centrality_df['node'].str.startswith(prefix_brick)]
        centrality_summary_brick_df = centrality_summary_brick_df.merge(out_degree_centrality_df, on="node")
    if k == "C_B307_Haystack.ttl":
        out_degree_centrality_df = out_degree_centrality_df[out_degree_centrality_df['node'].str.startswith(prefix_haystack)]
        centrality_summary_haystack_df = centrality_summary_haystack_df.merge(out_degree_centrality_df, on="node")
    if k == "C_B307_RECore.ttl":
        out_degree_centrality_df = out_degree_centrality_df[out_degree_centrality_df['node'].str.startswith(prefix_recore)]
        centrality_summary_recore_df = centrality_summary_recore_df.merge(out_degree_centrality_df, on="node")
    if k == "C_B307_DigitalBuilding.ttl":
        out_degree_centrality_df = out_degree_centrality_df[out_degree_centrality_df['node'].str.startswith(prefix_digitalbuilding)]
        centrality_summary_digitalbuilding_df = centrality_summary_digitalbuilding_df.merge(out_degree_centrality_df, on="node")
    
    # sort
    out_degree_centrality_df = out_degree_centrality_df.sort_values("out_degree_centrality", ascending = False)
    
    # print
    print (k)
    print (out_degree_centrality_df.head(10))
    print ("==================================================")
# Out:
# C_B307_Brick.ttl
#                                                                                node  \
# 6        http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#B1
# 71       http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#F1
# 43       http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#G1
# 57   http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AHU_G2
# 111  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AHU_G1
# 75   http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AHU_F1
# 8    http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AHU_F2
# 39   http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AHU_B1
# 142      http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#G2
# 190  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#FCU_F7
#
#      out_degree_centrality
# 6                 0.030738
# 71                0.028689
# 43                0.026639
# 57                0.024590
# 111               0.024590
# 75                0.024590
# 8                 0.024590
# 39                0.024590
# 142               0.024590
# 190               0.022541
# ==================================================
# C_B307_DigitalBuilding.ttl
#                                                                                                      node  \
# 72     http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground
# 30     http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1
# 109  http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Basement
# 16         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#B1
# 116        http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#F1
# 62         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#G1
# 192    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AHU_G2
# 41     http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AHU_F2
# 6          http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#G2
# 78     http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AHU_G1
#
#      out_degree_centrality
# 72                0.061966
# 30                0.057692
# 109               0.040598
# 16                0.034188
# 116               0.029915
# 62                0.027778
# 192               0.025641
# 41                0.025641
# 6                 0.025641
# 78                0.025641
# ==================================================
# C_B307_Haystack.ttl
#                                                                                              node  \
# 0    http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#AC_G3_CHWCoil
# 125   http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Ground_G.103
# 150  http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#AC_F3_HHWCoil
# 149   http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Ground_G.105
# 145   http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Ground_G.115
# 243   http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Ground_G.117
# 143   http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Ground_G.102
# 245   http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Level1_1.123
# 141  http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#AC_G3_HHWCoil
# 259   http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Level1_1.116
#
#      out_degree_centrality
# 0                 0.008511
# 125               0.008511
# 150               0.008511
# 149               0.008511
# 145               0.008511
# 243               0.008511
# 143               0.008511
# 245               0.008511
# 141               0.008511
# 259               0.008511
# ==================================================
# C_B307_RECore.ttl
#                                                                                            node  \
# 70               http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#B1
# 35               http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#F1
# 65               http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#G1
# 42               http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#G2
# 18           http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_F1
# 146          http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_F2
# 228          http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_G2
# 39           http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_G1
# 105          http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#FCU_B3
# 219  http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_G1_HHWCoil
#
#      out_degree_centrality
# 70                0.031120
# 35                0.029046
# 65                0.026971
# 42                0.026971
# 18                0.024896
# 146               0.024896
# 228               0.024896
# 39                0.024896
# 105               0.022822
# 219               0.022822
# ==================================================

# %% [markdown]
# ## 2. Graphical centrality

# %% [markdown]
# ### (1) Closeness centrality (path spread importance)

# %%
# closeness centrality
for k, v in dic.items():
    closeness_centrality_df = pd.DataFrame(data = nx.closeness_centrality(v).items(), 
                                           columns = ["node", "closeness_centrality"])
    # filter
    if k == "C_B307_Brick.ttl":
        closeness_centrality_df = closeness_centrality_df[closeness_centrality_df['node'].str.startswith(prefix_brick)]
        centrality_summary_brick_df = centrality_summary_brick_df.merge(closeness_centrality_df, on="node")
    if k == "C_B307_Haystack.ttl":
        closeness_centrality_df = closeness_centrality_df[closeness_centrality_df['node'].str.startswith(prefix_haystack)]
        centrality_summary_haystack_df = centrality_summary_haystack_df.merge(closeness_centrality_df, on="node")
    if k == "C_B307_RECore.ttl":
        closeness_centrality_df = closeness_centrality_df[closeness_centrality_df['node'].str.startswith(prefix_recore)]
        centrality_summary_recore_df = centrality_summary_recore_df.merge(closeness_centrality_df, on="node")
    if k == "C_B307_DigitalBuilding.ttl":
        closeness_centrality_df = closeness_centrality_df[closeness_centrality_df['node'].str.startswith(prefix_digitalbuilding)]
        centrality_summary_digitalbuilding_df = centrality_summary_digitalbuilding_df.merge(closeness_centrality_df, on="node")
    
    # sort
    closeness_centrality_df = closeness_centrality_df.sort_values("closeness_centrality", ascending = False)
    
    # print
    print (k)
    print (closeness_centrality_df.head(10))
    print ("==================================================")
# Out:
# C_B307_Brick.ttl
#                                                                                        node  \
# 326  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Basement_B.116
# 56          http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Boiler1
# 17         http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Chiller1
# 168     http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Building307
# 182          http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Ground
# 398        http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Basement
# 263          http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1
# 225  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#FCU_B3_CHWCoil
# 123  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#FCU_B4_CHWCoil
# 119  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#FCU_G7_CHWCoil
#
#      closeness_centrality
# 326              0.073493
# 56               0.066393
# 17               0.066393
# 168              0.010246
# 182              0.006706
# 398              0.006706
# 263              0.006706
# 225              0.004098
# 123              0.004098
# 119              0.004098
# ==================================================
# C_B307_DigitalBuilding.ttl
#                                                                                                            node  \
# 54          http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Boiler1
# 19         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Chiller1
# 42      http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Building307
# 138    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.110
# 169    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.109
# 284  http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Basement_B.107
# 246    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.104
# 110  http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Basement_B.108
# 108    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.123
# 165    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.112
#
#      closeness_centrality
# 54               0.069231
# 19               0.069231
# 42               0.010684
# 138              0.008654
# 169              0.008654
# 284              0.008654
# 246              0.008654
# 110              0.008654
# 108              0.008654
# 165              0.008654
# ==================================================
# C_B307_Haystack.ttl
#                                                                                            node  \
# 56   http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Building307
# 22        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Ground
# 28        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Level1
# 37      http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Basement
# 104           http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#B1
# 148           http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#F1
# 91            http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#G1
# 3             http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#G2
# 53        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#AHU_B1
# 43        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#AHU_F2
#
#      closeness_centrality
# 56               0.216726
# 22               0.062766
# 28               0.059593
# 37               0.041588
# 104              0.027660
# 148              0.023404
# 91               0.023404
# 3                0.021277
# 53               0.017730
# 43               0.017021
# ==================================================
# C_B307_RECore.ttl
#                                                                                                  node  \
# 80               http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#Chiller1
# 25                http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#Boiler1
# 3          http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_CHWCoil
# 151  http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_OutsideDamper
# 96          http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_ClgVlv
# 270         http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_Filter
# 134      http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_SupplyFan
# 104   http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_ReturnDamper
# 141         http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_HtgVlv
# 67         http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_HHWCoil
#
#      closeness_centrality
# 80               0.072871
# 25               0.066225
# 3                0.019450
# 151              0.017680
# 96               0.017680
# 270              0.017680
# 134              0.017680
# 104              0.017680
# 141              0.016696
# 67               0.016696
# ==================================================

# %% [markdown]
# ### (2) Betweenness centrality (In-between/broker/bridge/middleman importance)

# %%
# betweenness centrality
for k, v in dic.items():
    betweenness_centrality_df = pd.DataFrame(data = nx.betweenness_centrality(v).items(), 
                                           columns = ["node", "betweenness_centrality"])
    # filter
    if k == "C_B307_Brick.ttl":
        betweenness_centrality_df = betweenness_centrality_df[betweenness_centrality_df['node'].str.startswith(prefix_brick)]
        centrality_summary_brick_df = centrality_summary_brick_df.merge(betweenness_centrality_df, on="node")
    if k == "C_B307_Haystack.ttl":
        betweenness_centrality_df = betweenness_centrality_df[betweenness_centrality_df['node'].str.startswith(prefix_haystack)]
        centrality_summary_haystack_df = centrality_summary_haystack_df.merge(betweenness_centrality_df, on="node")
    if k == "C_B307_RECore.ttl":
        betweenness_centrality_df = betweenness_centrality_df[betweenness_centrality_df['node'].str.startswith(prefix_recore)]
        centrality_summary_recore_df = centrality_summary_recore_df.merge(betweenness_centrality_df, on="node")
    if k == "C_B307_DigitalBuilding.ttl":
        betweenness_centrality_df = betweenness_centrality_df[betweenness_centrality_df['node'].str.startswith(prefix_digitalbuilding)]
        centrality_summary_digitalbuilding_df = centrality_summary_digitalbuilding_df.merge(betweenness_centrality_df, on="node")
    
    # sort
    betweenness_centrality_df = betweenness_centrality_df.sort_values("betweenness_centrality", ascending = False)
    
    # print
    print (k)
    print (betweenness_centrality_df.head(10))
    print ("==================================================")
# Out:
# C_B307_Brick.ttl
#                                                                                        node  \
# 56          http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Boiler1
# 17         http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Chiller1
# 326  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Basement_B.116
# 168     http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Building307
# 6                http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#B1
# 71               http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#F1
# 43               http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#G1
# 142              http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#G2
# 4                http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#F2
# 62    http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AC_G6_CHWCoil
#
#      betweenness_centrality
# 56                 0.001022
# 17                 0.001022
# 326                0.000774
# 168                0.000210
# 6                  0.000147
# 71                 0.000135
# 43                 0.000126
# 142                0.000101
# 4                  0.000084
# 62                 0.000061
# ==================================================
# C_B307_DigitalBuilding.ttl
#                                                                                                         node  \
# 42   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Building307
# 72        http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground
# 30        http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1
# 109     http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Basement
# 54       http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Boiler1
# 19      http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Chiller1
# 16            http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#B1
# 116           http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#F1
# 62            http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#G1
# 6             http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#G2
#
#      betweenness_centrality
# 42                 0.002860
# 72                 0.001329
# 30                 0.001228
# 109                0.000843
# 54                 0.000494
# 19                 0.000494
# 16                 0.000142
# 116                0.000124
# 62                 0.000114
# 6                  0.000105
# ==================================================
# C_B307_Haystack.ttl
#                                                                                            node  \
# 56   http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Building307
# 22        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Ground
# 28        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Level1
# 37      http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Basement
# 70        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#FCU_F7
# 61        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#FCU_B4
# 47        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#FCU_B3
# 96        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#FCU_B2
# 112       http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#FCU_G7
# 34         http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#AC_G6
#
#      betweenness_centrality
# 56                 0.002041
# 22                 0.000719
# 28                 0.000687
# 37                 0.000494
# 70                 0.000445
# 61                 0.000445
# 47                 0.000445
# 96                 0.000445
# 112                0.000445
# 34                 0.000363
# ==================================================
# C_B307_RECore.ttl
#                                                                                            node  \
# 80         http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#Chiller1
# 25          http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#Boiler1
# 40      http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#Building307
# 3    http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_CHWCoil
# 136  http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_F1_HHWCoil
# 2    http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_F2_HHWCoil
# 24   http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_G2_HHWCoil
# 219  http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_G1_HHWCoil
# 67   http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_HHWCoil
# 70               http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#B1
#
#      betweenness_centrality
# 80                 0.000543
# 25                 0.000457
# 40                 0.000237
# 3                  0.000211
# 136                0.000205
# 2                  0.000205
# 24                 0.000205
# 219                0.000205
# 67                 0.000151
# 70                 0.000147
# ==================================================

# %% [markdown]
# ## 3. Logical centrality

# %% [markdown]
# ###  (1) PageRank centrality

# %%
# pagerank centrality
for k, v in dic.items():
    pagerank_centrality_df = pd.DataFrame(data = nx.pagerank(v).items(), 
                                           columns = ["node", "pagerank_centrality"])
    # filter
    if k == "C_B307_Brick.ttl":
        pagerank_centrality_df = pagerank_centrality_df[pagerank_centrality_df['node'].str.startswith(prefix_brick)]
        centrality_summary_brick_df = centrality_summary_brick_df.merge(pagerank_centrality_df, on="node")
    if k == "C_B307_Haystack.ttl":
        pagerank_centrality_df = pagerank_centrality_df[pagerank_centrality_df['node'].str.startswith(prefix_haystack)]
        centrality_summary_haystack_df = centrality_summary_haystack_df.merge(pagerank_centrality_df, on="node")
    if k == "C_B307_RECore.ttl":
        pagerank_centrality_df = pagerank_centrality_df[pagerank_centrality_df['node'].str.startswith(prefix_recore)]
        centrality_summary_recore_df = centrality_summary_recore_df.merge(pagerank_centrality_df, on="node")
    if k == "C_B307_DigitalBuilding.ttl":
        pagerank_centrality_df = pagerank_centrality_df[pagerank_centrality_df['node'].str.startswith(prefix_digitalbuilding)]
        centrality_summary_digitalbuilding_df = centrality_summary_digitalbuilding_df.merge(pagerank_centrality_df, on="node")
    
    # sort
    pagerank_centrality_df = pagerank_centrality_df.sort_values("pagerank_centrality", ascending = False)
    
    # print
    print (k)
    print (pagerank_centrality_df.head(10))
    print ("==================================================")
    
    print(centrality_summary_digitalbuilding_df)
# Out:
# C_B307_Brick.ttl
#                                                                                        node  \
# 17         http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Chiller1
# 56          http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Boiler1
# 326  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Basement_B.116
# 166   http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AC_G5_CHWCoil
# 309   http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AC_F3_CHWCoil
# 197   http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AC_F5_CHWCoil
# 35    http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AC_G4_CHWCoil
# 266   http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AC_G6_HHWCoil
# 267    http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Ground_G.104
# 32     http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Ground_G.119
#
#      pagerank_centrality
# 17              0.011156
# 56              0.011156
# 326             0.007699
# 166             0.001937
# 309             0.001937
# 197             0.001937
# 35              0.001937
# 266             0.001937
# 267             0.001937
# 32              0.001937
# ==================================================
#                                                                                                                  node  \
# 0                   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AC_G6
# 1    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AHU_G2_OutsideDamper
# 2                      http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#F3
# 3                      http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#G2
# 4            http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.121
# ..                                                                                                                ...
# 221         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_F7_Filter
# 222         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_F7_HtgVlv
# 223         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_G7_Filter
# 224  http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AHU_G1_OutsideDamper
# 225          http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.122
#
#      in_degree_centrality  out_degree_centrality  closeness_centrality  \
# 0                0.000000               0.019231              0.000000
# 1                0.002137               0.004274              0.002137
# 2                0.002137               0.006410              0.002137
# 3                0.002137               0.025641              0.002137
# 4                0.004274               0.004274              0.007597
# ..                    ...                    ...                   ...
# 221              0.002137               0.004274              0.002137
# 222              0.002137               0.006410              0.002137
# 223              0.002137               0.004274              0.002137
# 224              0.002137               0.004274              0.002137
# 225              0.004274               0.004274              0.007597
#
#      betweenness_centrality
# 0                  0.000000
# 1                  0.000007
# 2                  0.000009
# 3                  0.000105
# 4                  0.000038
# ..                      ...
# 221                0.000009
# 222                0.000007
# 223                0.000009
# 224                0.000007
# 225                0.000038
#
# [226 rows x 5 columns]
# C_B307_DigitalBuilding.ttl
#                                                                                                            node  \
# 54          http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Boiler1
# 19         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Chiller1
# 18   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_B2_CHWCoil
# 203    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.118
# 108    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.123
# 169    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.109
# 246    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.104
# 14     http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.119
# 71     http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.104
# 126    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.124
#
#      pagerank_centrality
# 54              0.011496
# 19              0.011496
# 18              0.002398
# 203             0.002051
# 108             0.002051
# 169             0.002051
# 246             0.002051
# 14              0.002047
# 71              0.002047
# 126             0.002047
# ==================================================
#                                                                                                                  node  \
# 0                   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AC_G6
# 1    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AHU_G2_OutsideDamper
# 2                      http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#F3
# 3                      http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#G2
# 4            http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.121
# ..                                                                                                                ...
# 221         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_F7_Filter
# 222         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_F7_HtgVlv
# 223         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_G7_Filter
# 224  http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AHU_G1_OutsideDamper
# 225          http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.122
#
#      in_degree_centrality  out_degree_centrality  closeness_centrality  \
# 0                0.000000               0.019231              0.000000
# 1                0.002137               0.004274              0.002137
# 2                0.002137               0.006410              0.002137
# 3                0.002137               0.025641              0.002137
# 4                0.004274               0.004274              0.007597
# ..                    ...                    ...                   ...
# 221              0.002137               0.004274              0.002137
# 222              0.002137               0.006410              0.002137
# 223              0.002137               0.004274              0.002137
# 224              0.002137               0.004274              0.002137
# 225              0.004274               0.004274              0.007597
#
#      betweenness_centrality  pagerank_centrality
# 0                  0.000000             0.001421
# 1                  0.000007             0.001522
# 2                  0.000009             0.001555
# 3                  0.000105             0.001522
# 4                  0.000038             0.001580
# ..                      ...                  ...
# 221                0.000009             0.001531
# 222                0.000007             0.001531
# 223                0.000009             0.001531
# 224                0.000007             0.001522
# 225                0.000038             0.001606
#
# [226 rows x 6 columns]
# C_B307_Haystack.ttl
#                                                                                            node  \
# 56   http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Building307
# 22        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Ground
# 28        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Level1
# 37      http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Basement
# 104           http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#B1
# 53        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#AHU_B1
# 148           http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#F1
# 91            http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#G1
# 43        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#AHU_F2
# 64        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#AHU_G2
#
#      pagerank_centrality
# 56              0.030634
# 22              0.009651
# 28              0.009089
# 37              0.006718
# 104             0.004971
# 53              0.004441
# 148             0.004409
# 91              0.004409
# 43              0.004288
# 64              0.004288
# ==================================================
#                                                                                                                  node  \
# 0                   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AC_G6
# 1    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AHU_G2_OutsideDamper
# 2                      http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#F3
# 3                      http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#G2
# 4            http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.121
# ..                                                                                                                ...
# 221         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_F7_Filter
# 222         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_F7_HtgVlv
# 223         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_G7_Filter
# 224  http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AHU_G1_OutsideDamper
# 225          http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.122
#
#      in_degree_centrality  out_degree_centrality  closeness_centrality  \
# 0                0.000000               0.019231              0.000000
# 1                0.002137               0.004274              0.002137
# 2                0.002137               0.006410              0.002137
# 3                0.002137               0.025641              0.002137
# 4                0.004274               0.004274              0.007597
# ..                    ...                    ...                   ...
# 221              0.002137               0.004274              0.002137
# 222              0.002137               0.006410              0.002137
# 223              0.002137               0.004274              0.002137
# 224              0.002137               0.004274              0.002137
# 225              0.004274               0.004274              0.007597
#
#      betweenness_centrality  pagerank_centrality
# 0                  0.000000             0.001421
# 1                  0.000007             0.001522
# 2                  0.000009             0.001555
# 3                  0.000105             0.001522
# 4                  0.000038             0.001580
# ..                      ...                  ...
# 221                0.000009             0.001531
# 222                0.000007             0.001531
# 223                0.000009             0.001531
# 224                0.000007             0.001522
# 225                0.000038             0.001606
#
# [226 rows x 6 columns]
# C_B307_RECore.ttl
#                                                                                                  node  \
# 80               http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#Chiller1
# 25                http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#Boiler1
# 67         http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_HHWCoil
# 3          http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_CHWCoil
# 141         http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_HtgVlv
# 134      http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_SupplyFan
# 96          http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_ClgVlv
# 270         http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_Filter
# 104   http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_ReturnDamper
# 151  http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_OutsideDamper
#
#      pagerank_centrality
# 80              0.008593
# 25              0.007200
# 67              0.002553
# 3               0.002553
# 141             0.002105
# 134             0.002105
# 96              0.002105
# 270             0.002105
# 104             0.002105
# 151             0.002105
# ==================================================
#                                                                                                                  node  \
# 0                   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AC_G6
# 1    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AHU_G2_OutsideDamper
# 2                      http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#F3
# 3                      http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#G2
# 4            http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.121
# ..                                                                                                                ...
# 221         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_F7_Filter
# 222         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_F7_HtgVlv
# 223         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_G7_Filter
# 224  http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AHU_G1_OutsideDamper
# 225          http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.122
#
#      in_degree_centrality  out_degree_centrality  closeness_centrality  \
# 0                0.000000               0.019231              0.000000
# 1                0.002137               0.004274              0.002137
# 2                0.002137               0.006410              0.002137
# 3                0.002137               0.025641              0.002137
# 4                0.004274               0.004274              0.007597
# ..                    ...                    ...                   ...
# 221              0.002137               0.004274              0.002137
# 222              0.002137               0.006410              0.002137
# 223              0.002137               0.004274              0.002137
# 224              0.002137               0.004274              0.002137
# 225              0.004274               0.004274              0.007597
#
#      betweenness_centrality  pagerank_centrality
# 0                  0.000000             0.001421
# 1                  0.000007             0.001522
# 2                  0.000009             0.001555
# 3                  0.000105             0.001522
# 4                  0.000038             0.001580
# ..                      ...                  ...
# 221                0.000009             0.001531
# 222                0.000007             0.001531
# 223                0.000009             0.001531
# 224                0.000007             0.001522
# 225                0.000038             0.001606
#
# [226 rows x 6 columns]

# %% [markdown]
# ### (2) Hit: Authority and Hub scores (inward and outward importance)

# %%
for k, v in dic.items():
    # hits
    hub_scores, auth_scores = nx.hits(v)
    
    # hub score
    hub_centrality_df = pd.DataFrame(data = hub_scores.items(), 
                                           columns = ["node", "hub_centrality"])
    # filter
    if k == "C_B307_Brick.ttl":
        hub_centrality_df = hub_centrality_df[hub_centrality_df['node'].str.startswith(prefix_brick)]
        centrality_summary_brick_df = centrality_summary_brick_df.merge(hub_centrality_df, on="node")
    if k == "C_B307_Haystack.ttl":
        hub_centrality_df = hub_centrality_df[hub_centrality_df['node'].str.startswith(prefix_haystack)]
        centrality_summary_haystack_df = centrality_summary_haystack_df.merge(hub_centrality_df, on="node")
    if k == "C_B307_RECore.ttl":
        hub_centrality_df = hub_centrality_df[hub_centrality_df['node'].str.startswith(prefix_recore)]
        centrality_summary_recore_df = centrality_summary_recore_df.merge(hub_centrality_df, on="node")
    if k == "C_B307_DigitalBuilding.ttl":
        hub_centrality_df = hub_centrality_df[hub_centrality_df['node'].str.startswith(prefix_digitalbuilding)]
        centrality_summary_digitalbuilding_df = centrality_summary_digitalbuilding_df.merge(hub_centrality_df, on="node")
    
    # sort
    hub_centrality_df = hub_centrality_df.sort_values("hub_centrality", ascending = False)
    
    # print
    print (k)
    print (hub_centrality_df.head(10))
    print ("==================================================")
    
    
    # authority score
    auth_centrality_df = pd.DataFrame(data = auth_scores.items(), 
                                           columns = ["node", "auth_centrality"])
    # filter
    if k == "C_B307_Brick.ttl":
        auth_centrality_df = auth_centrality_df[auth_centrality_df['node'].str.startswith(prefix_brick)]
        centrality_summary_brick_df = centrality_summary_brick_df.merge(auth_centrality_df, on="node")
    if k == "C_B307_Haystack.ttl":
        auth_centrality_df = auth_centrality_df[auth_centrality_df['node'].str.startswith(prefix_haystack)]
        centrality_summary_haystack_df = centrality_summary_haystack_df.merge(auth_centrality_df, on="node")
    if k == "C_B307_RECore.ttl":
        auth_centrality_df = auth_centrality_df[auth_centrality_df['node'].str.startswith(prefix_recore)]
        centrality_summary_recore_df = centrality_summary_recore_df.merge(auth_centrality_df, on="node")
    if k == "C_B307_DigitalBuilding.ttl":
        auth_centrality_df = auth_centrality_df[auth_centrality_df['node'].str.startswith(prefix_digitalbuilding)]
        centrality_summary_digitalbuilding_df = centrality_summary_digitalbuilding_df.merge(auth_centrality_df, on="node")
    
    # sort
    auth_centrality_df = auth_centrality_df.sort_values("auth_centrality", ascending = False)
    
    # print
    print (k)
    print (auth_centrality_df.head(10))
    print ("==================================================")
    
    print(centrality_summary_digitalbuilding_df)
# Out:
# C_B307_Brick.ttl
#                                                                                        node  \
# 162  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AHU_F2_HHWCoil
# 55   http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AHU_F1_HHWCoil
# 241   http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AC_F5_HHWCoil
# 59   http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AHU_G2_HHWCoil
# 129   http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AC_G5_HHWCoil
# 112  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#FCU_B2_HHWCoil
# 21   http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#FCU_B3_HHWCoil
# 385  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AHU_B1_HHWCoil
# 248  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AHU_G1_HHWCoil
# 324   http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AC_F4_HHWCoil
#
#      hub_centrality
# 162        0.107106
# 55         0.107106
# 241        0.107106
# 59         0.107106
# 129        0.107106
# 112        0.107106
# 21         0.107106
# 385        0.107106
# 248        0.107106
# 324        0.107106
# ==================================================
# C_B307_Brick.ttl
#                                                                                        node  \
# 56          http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Boiler1
# 198  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Basement_B.114
# 12   http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Basement_B.106
# 307  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Basement_B.104
# 238  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Basement_B.110
# 120  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Basement_B.102
# 336  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Basement_B.112
# 79   http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Basement_B.101
# 167  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Basement_B.103
# 139  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Basement_B.115
#
#      auth_centrality
# 56      6.426344e-01
# 198     3.393483e-17
# 12      3.393483e-17
# 307     3.393483e-17
# 238     3.393483e-17
# 120     3.393483e-17
# 336     3.393483e-17
# 79      3.393483e-17
# 167     3.393483e-17
# 139     3.393483e-17
# ==================================================
#                                                                                                                  node  \
# 0                   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AC_G6
# 1    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AHU_G2_OutsideDamper
# 2                      http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#F3
# 3                      http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#G2
# 4            http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.121
# ..                                                                                                                ...
# 221         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_F7_Filter
# 222         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_F7_HtgVlv
# 223         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_G7_Filter
# 224  http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AHU_G1_OutsideDamper
# 225          http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.122
#
#      in_degree_centrality  out_degree_centrality  closeness_centrality  \
# 0                0.000000               0.019231              0.000000
# 1                0.002137               0.004274              0.002137
# 2                0.002137               0.006410              0.002137
# 3                0.002137               0.025641              0.002137
# 4                0.004274               0.004274              0.007597
# ..                    ...                    ...                   ...
# 221              0.002137               0.004274              0.002137
# 222              0.002137               0.006410              0.002137
# 223              0.002137               0.004274              0.002137
# 224              0.002137               0.004274              0.002137
# 225              0.004274               0.004274              0.007597
#
#      betweenness_centrality  pagerank_centrality
# 0                  0.000000             0.001421
# 1                  0.000007             0.001522
# 2                  0.000009             0.001555
# 3                  0.000105             0.001522
# 4                  0.000038             0.001580
# ..                      ...                  ...
# 221                0.000009             0.001531
# 222                0.000007             0.001531
# 223                0.000009             0.001531
# 224                0.000007             0.001522
# 225                0.000038             0.001606
#
# [226 rows x 6 columns]
# C_B307_DigitalBuilding.ttl
#                                                                                                            node  \
# 423    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.122
# 145    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.105
# 333  http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Basement_B.115
# 317    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.116
# 315  http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Basement_B.113
# 138    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.110
# 63     http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.102
# 308    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.113
# 59     http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.105
# 171  http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Basement_B.102
#
#      hub_centrality
# 423        0.014493
# 145        0.014493
# 333        0.014493
# 317        0.014493
# 315        0.014493
# 138        0.014493
# 63         0.014493
# 308        0.014493
# 59         0.014493
# 171        0.014493
# ==================================================
# C_B307_DigitalBuilding.ttl
#                                                                                                           node  \
# 54         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Boiler1
# 19        http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Chiller1
# 267   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.103
# 202  http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.117a
# 147   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.112
# 45    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.117
# 249   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.102
# 263   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.114
# 206   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.111
# 129   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.115
#
#      auth_centrality
# 54      1.502810e-16
# 19      1.040206e-16
# 267     6.192193e-18
# 202     6.192193e-18
# 147     6.192193e-18
# 45      6.192193e-18
# 249     6.192193e-18
# 263     6.192193e-18
# 206     6.192193e-18
# 129     6.192193e-18
# ==================================================
#                                                                                                                  node  \
# 0                   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AC_G6
# 1    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AHU_G2_OutsideDamper
# 2                      http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#F3
# 3                      http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#G2
# 4            http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.121
# ..                                                                                                                ...
# 221         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_F7_Filter
# 222         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_F7_HtgVlv
# 223         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_G7_Filter
# 224  http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AHU_G1_OutsideDamper
# 225          http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.122
#
#      in_degree_centrality  out_degree_centrality  closeness_centrality  \
# 0                0.000000               0.019231              0.000000
# 1                0.002137               0.004274              0.002137
# 2                0.002137               0.006410              0.002137
# 3                0.002137               0.025641              0.002137
# 4                0.004274               0.004274              0.007597
# ..                    ...                    ...                   ...
# 221              0.002137               0.004274              0.002137
# 222              0.002137               0.006410              0.002137
# 223              0.002137               0.004274              0.002137
# 224              0.002137               0.004274              0.002137
# 225              0.004274               0.004274              0.007597
#
#      betweenness_centrality  pagerank_centrality  hub_centrality  \
# 0                  0.000000             0.001421   -2.043805e-18
# 1                  0.000007             0.001522   -2.472879e-19
# 2                  0.000009             0.001555   -3.524036e-19
# 3                  0.000105             0.001522   -4.586616e-19
# 4                  0.000038             0.001580    1.449275e-02
# ..                      ...                  ...             ...
# 221                0.000009             0.001531   -4.815758e-20
# 222                0.000007             0.001531    5.116382e-19
# 223                0.000009             0.001531   -4.731642e-20
# 224                0.000007             0.001522   -2.474569e-19
# 225                0.000038             0.001606    1.449275e-02
#
#      auth_centrality
# 0      -0.000000e+00
# 1      -2.804744e-18
# 2      -5.507773e-18
# 3      -2.804744e-18
# 4      -7.784937e-19
# ..               ...
# 221    -3.347725e-18
# 222    -3.347725e-18
# 223    -3.301592e-18
# 224     1.183326e-19
# 225     3.924799e-18
#
# [226 rows x 8 columns]
# C_B307_Haystack.ttl
#                                                                                              node  \
# 191   http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Ground_G.118
# 21   http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Ground_G.118a
# 143   http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Ground_G.102
# 162   http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Ground_G.101
# 100   http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Ground_G.113
# 48    http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Ground_G.114
# 243   http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Ground_G.117
# 125   http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Ground_G.103
# 131   http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Ground_G.116
# 145   http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Ground_G.115
#
#      hub_centrality
# 191        0.015631
# 21         0.015631
# 143        0.015478
# 162        0.015478
# 100        0.015478
# 48         0.015478
# 243        0.015478
# 125        0.015478
# 131        0.015478
# 145        0.015478
# ==================================================
# C_B307_Haystack.ttl
#                                                                                         node  \
# 22     http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Ground
# 28     http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Level1
# 37   http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Basement
# 104        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#B1
# 91         http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#G1
# 148        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#F1
# 3          http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#G2
# 281        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#F2
# 239        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#G7
# 140        http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#F7
#
#      auth_centrality
# 22          0.102196
# 28          0.090727
# 37          0.057249
# 104         0.045080
# 91          0.042770
# 148         0.041294
# 3           0.038381
# 281         0.029072
# 239         0.007139
# 140         0.006907
# ==================================================
#                                                                                                                  node  \
# 0                   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AC_G6
# 1    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AHU_G2_OutsideDamper
# 2                      http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#F3
# 3                      http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#G2
# 4            http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.121
# ..                                                                                                                ...
# 221         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_F7_Filter
# 222         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_F7_HtgVlv
# 223         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_G7_Filter
# 224  http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AHU_G1_OutsideDamper
# 225          http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.122
#
#      in_degree_centrality  out_degree_centrality  closeness_centrality  \
# 0                0.000000               0.019231              0.000000
# 1                0.002137               0.004274              0.002137
# 2                0.002137               0.006410              0.002137
# 3                0.002137               0.025641              0.002137
# 4                0.004274               0.004274              0.007597
# ..                    ...                    ...                   ...
# 221              0.002137               0.004274              0.002137
# 222              0.002137               0.006410              0.002137
# 223              0.002137               0.004274              0.002137
# 224              0.002137               0.004274              0.002137
# 225              0.004274               0.004274              0.007597
#
#      betweenness_centrality  pagerank_centrality  hub_centrality  \
# 0                  0.000000             0.001421   -2.043805e-18
# 1                  0.000007             0.001522   -2.472879e-19
# 2                  0.000009             0.001555   -3.524036e-19
# 3                  0.000105             0.001522   -4.586616e-19
# 4                  0.000038             0.001580    1.449275e-02
# ..                      ...                  ...             ...
# 221                0.000009             0.001531   -4.815758e-20
# 222                0.000007             0.001531    5.116382e-19
# 223                0.000009             0.001531   -4.731642e-20
# 224                0.000007             0.001522   -2.474569e-19
# 225                0.000038             0.001606    1.449275e-02
#
#      auth_centrality
# 0      -0.000000e+00
# 1      -2.804744e-18
# 2      -5.507773e-18
# 3      -2.804744e-18
# 4      -7.784937e-19
# ..               ...
# 221    -3.347725e-18
# 222    -3.347725e-18
# 223    -3.301592e-18
# 224     1.183326e-19
# 225     3.924799e-18
#
# [226 rows x 8 columns]
# C_B307_RECore.ttl
#                                                                                            node  \
# 219  http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_G1_HHWCoil
# 24   http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_G2_HHWCoil
# 67   http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_HHWCoil
# 2    http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_F2_HHWCoil
# 136  http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_F1_HHWCoil
# 109   http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AC_F3_HHWCoil
# 113   http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AC_G3_HHWCoil
# 142   http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AC_F6_HHWCoil
# 221   http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AC_F4_HHWCoil
# 209  http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#FCU_G7_HHWCoil
#
#      hub_centrality
# 219        0.060672
# 24         0.060672
# 67         0.060672
# 2          0.060672
# 136        0.060672
# 109        0.023997
# 113        0.023997
# 142        0.023997
# 221        0.023997
# 209        0.023997
# ==================================================
# C_B307_RECore.ttl
#                                                                                                  node  \
# 25                http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#Boiler1
# 80               http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#Chiller1
# 3          http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_CHWCoil
# 67         http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_HHWCoil
# 96          http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_ClgVlv
# 104   http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_ReturnDamper
# 134      http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_SupplyFan
# 141         http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_HtgVlv
# 151  http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_OutsideDamper
# 270         http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_Filter
#
#      auth_centrality
# 25          0.095717
# 80          0.056594
# 3           0.047959
# 67          0.047959
# 96          0.047189
# 104         0.047189
# 134         0.047189
# 141         0.047189
# 151         0.047189
# 270         0.047189
# ==================================================
#                                                                                                                  node  \
# 0                   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AC_G6
# 1    http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AHU_G2_OutsideDamper
# 2                      http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#F3
# 3                      http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#G2
# 4            http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Ground_G.121
# ..                                                                                                                ...
# 221         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_F7_Filter
# 222         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_F7_HtgVlv
# 223         http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#FCU_G7_Filter
# 224  http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#AHU_G1_OutsideDamper
# 225          http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Level1_1.122
#
#      in_degree_centrality  out_degree_centrality  closeness_centrality  \
# 0                0.000000               0.019231              0.000000
# 1                0.002137               0.004274              0.002137
# 2                0.002137               0.006410              0.002137
# 3                0.002137               0.025641              0.002137
# 4                0.004274               0.004274              0.007597
# ..                    ...                    ...                   ...
# 221              0.002137               0.004274              0.002137
# 222              0.002137               0.006410              0.002137
# 223              0.002137               0.004274              0.002137
# 224              0.002137               0.004274              0.002137
# 225              0.004274               0.004274              0.007597
#
#      betweenness_centrality  pagerank_centrality  hub_centrality  \
# 0                  0.000000             0.001421   -2.043805e-18
# 1                  0.000007             0.001522   -2.472879e-19
# 2                  0.000009             0.001555   -3.524036e-19
# 3                  0.000105             0.001522   -4.586616e-19
# 4                  0.000038             0.001580    1.449275e-02
# ..                      ...                  ...             ...
# 221                0.000009             0.001531   -4.815758e-20
# 222                0.000007             0.001531    5.116382e-19
# 223                0.000009             0.001531   -4.731642e-20
# 224                0.000007             0.001522   -2.474569e-19
# 225                0.000038             0.001606    1.449275e-02
#
#      auth_centrality
# 0      -0.000000e+00
# 1      -2.804744e-18
# 2      -5.507773e-18
# 3      -2.804744e-18
# 4      -7.784937e-19
# ..               ...
# 221    -3.347725e-18
# 222    -3.347725e-18
# 223    -3.301592e-18
# 224     1.183326e-19
# 225     3.924799e-18
#
# [226 rows x 8 columns]

# %%
print(centrality_summary_brick_df)
# Out:
#                                                                                          node  \
# 0        http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AC_F3_ClgVlv
# 1       http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AHU_G1_HtgVlv
# 2                  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#F2
# 3        http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1_1.119
# 4                  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#B1
# ..                                                                                        ...
# 221          http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Basement
# 222      http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1_1.100
# 223      http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1_1.114
# 224      http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Level1_1.111
# 225  http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#FCU_B4_SupplyFan
#
#      in_degree_centrality  out_degree_centrality  closeness_centrality  \
# 0                0.002049               0.006148              0.002049
# 1                0.002049               0.006148              0.002049
# 2                0.002049               0.020492              0.002049
# 3                0.002049               0.004098              0.002732
# 4                0.002049               0.030738              0.002049
# ..                    ...                    ...                   ...
# 221              0.002049               0.004098              0.006706
# 222              0.002049               0.004098              0.002732
# 223              0.002049               0.004098              0.002732
# 224              0.002049               0.004098              0.002732
# 225              0.002049               0.004098              0.002049
#
#      betweenness_centrality  pagerank_centrality  hub_centrality  \
# 0                  0.000008             0.001509    1.666224e-18
# 1                  0.000008             0.001477   -2.670615e-18
# 2                  0.000084             0.001477    4.285841e-17
# 3                  0.000011             0.001505   -1.714686e-18
# 4                  0.000147             0.001477    6.422970e-17
# ..                      ...                  ...             ...
# 221                0.000050             0.001697   -2.286677e-20
# 222                0.000010             0.001469    1.100877e-18
# 223                0.000011             0.001469    5.241214e-19
# 224                0.000017             0.001469    4.324084e-19
# 225                0.000008             0.001486   -3.976039e-19
#
#      auth_centrality
# 0       5.041958e-18
# 1      -6.536133e-18
# 2      -6.041983e-18
# 3       2.350091e-17
# 4       2.521847e-19
# ..               ...
# 221     1.722143e-18
# 222     3.078877e-17
# 223     3.078877e-17
# 224     3.078877e-17
# 225     9.574712e-18
#
# [226 rows x 8 columns]

# %%
centrality_ranks = centrality_summary_brick_df.rank(ascending=False, 
                                           numeric_only=True, 
                                           method="dense").astype(int)
centrality_ranks.insert(loc=0, column='node', value=centrality_summary_brick_df["node"])
centrality_ranks.sort_values("in_degree_centrality").style.background_gradient(subset=list(centrality_ranks.columns[1:]))
# Out:
# <style type="text/css">
# #T_f67bc_row0_col1, #T_f67bc_row0_col4, #T_f67bc_row0_col5, #T_f67bc_row0_col7, #T_f67bc_row1_col1, #T_f67bc_row1_col4, #T_f67bc_row1_col5, #T_f67bc_row3_col6, #T_f67bc_row6_col6, #T_f67bc_row7_col6, #T_f67bc_row12_col6, #T_f67bc_row13_col6, #T_f67bc_row15_col6, #T_f67bc_row19_col6, #T_f67bc_row21_col6, #T_f67bc_row23_col6, #T_f67bc_row27_col6, #T_f67bc_row29_col6, #T_f67bc_row30_col6, #T_f67bc_row33_col6, #T_f67bc_row35_col6, #T_f67bc_row37_col6, #T_f67bc_row40_col6, #T_f67bc_row44_col6, #T_f67bc_row49_col3, #T_f67bc_row52_col6, #T_f67bc_row152_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_f67bc_row0_col2, #T_f67bc_row1_col2, #T_f67bc_row3_col2, #T_f67bc_row4_col2, #T_f67bc_row6_col2, #T_f67bc_row7_col2, #T_f67bc_row9_col2, #T_f67bc_row10_col2, #T_f67bc_row11_col2, #T_f67bc_row12_col2, #T_f67bc_row12_col7, #T_f67bc_row13_col2, #T_f67bc_row14_col2, #T_f67bc_row15_col2, #T_f67bc_row17_col2, #T_f67bc_row18_col2, #T_f67bc_row19_col2, #T_f67bc_row21_col2, #T_f67bc_row22_col2, #T_f67bc_row23_col2, #T_f67bc_row26_col2, #T_f67bc_row27_col2, #T_f67bc_row29_col2, #T_f67bc_row30_col2, #T_f67bc_row32_col2, #T_f67bc_row33_col2, #T_f67bc_row34_col2, #T_f67bc_row35_col2, #T_f67bc_row37_col2, #T_f67bc_row38_col2, #T_f67bc_row39_col2, #T_f67bc_row40_col2, #T_f67bc_row41_col2, #T_f67bc_row44_col2, #T_f67bc_row45_col2, #T_f67bc_row47_col2, #T_f67bc_row50_col2, #T_f67bc_row52_col2, #T_f67bc_row53_col2, #T_f67bc_row55_col2, #T_f67bc_row57_col2, #T_f67bc_row60_col2, #T_f67bc_row64_col2, #T_f67bc_row64_col6, #T_f67bc_row65_col2, #T_f67bc_row71_col2, #T_f67bc_row72_col2, #T_f67bc_row75_col2, #T_f67bc_row76_col2, #T_f67bc_row79_col2, #T_f67bc_row81_col2, #T_f67bc_row83_col2, #T_f67bc_row85_col2, #T_f67bc_row93_col2, #T_f67bc_row101_col2, #T_f67bc_row106_col2, #T_f67bc_row107_col2, #T_f67bc_row110_col2, #T_f67bc_row114_col2, #T_f67bc_row120_col2, #T_f67bc_row121_col2, #T_f67bc_row124_col2, #T_f67bc_row125_col2, #T_f67bc_row129_col2, #T_f67bc_row132_col2, #T_f67bc_row137_col2, #T_f67bc_row140_col2, #T_f67bc_row144_col2, #T_f67bc_row148_col2, #T_f67bc_row149_col2, #T_f67bc_row156_col2, #T_f67bc_row160_col2, #T_f67bc_row162_col2, #T_f67bc_row166_col2, #T_f67bc_row169_col2, #T_f67bc_row173_col2, #T_f67bc_row175_col2, #T_f67bc_row177_col2, #T_f67bc_row180_col2, #T_f67bc_row181_col2, #T_f67bc_row185_col2, #T_f67bc_row189_col2, #T_f67bc_row190_col2, #T_f67bc_row195_col2, #T_f67bc_row197_col2, #T_f67bc_row198_col2, #T_f67bc_row201_col2, #T_f67bc_row203_col2 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_f67bc_row0_col3, #T_f67bc_row1_col3, #T_f67bc_row215_col6 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_f67bc_row0_col6 {
#   background-color: #358fc0;
#   color: #f1f1f1;
# }
# #T_f67bc_row1_col6 {
#   background-color: #3790c0;
#   color: #f1f1f1;
# }
# #T_f67bc_row1_col7, #T_f67bc_row4_col6, #T_f67bc_row5_col2, #T_f67bc_row8_col2, #T_f67bc_row9_col6, #T_f67bc_row10_col6, #T_f67bc_row11_col6, #T_f67bc_row14_col6, #T_f67bc_row16_col2, #T_f67bc_row17_col6, #T_f67bc_row18_col6, #T_f67bc_row20_col2, #T_f67bc_row22_col6, #T_f67bc_row24_col2, #T_f67bc_row25_col2, #T_f67bc_row26_col6, #T_f67bc_row28_col2, #T_f67bc_row31_col2, #T_f67bc_row32_col6, #T_f67bc_row34_col6, #T_f67bc_row36_col2, #T_f67bc_row38_col6, #T_f67bc_row39_col6, #T_f67bc_row41_col6, #T_f67bc_row42_col2, #T_f67bc_row43_col2, #T_f67bc_row45_col6, #T_f67bc_row46_col2, #T_f67bc_row47_col6, #T_f67bc_row48_col2, #T_f67bc_row49_col2, #T_f67bc_row50_col6, #T_f67bc_row51_col2, #T_f67bc_row53_col6, #T_f67bc_row54_col2, #T_f67bc_row56_col2, #T_f67bc_row58_col2, #T_f67bc_row59_col2, #T_f67bc_row61_col2, #T_f67bc_row62_col2, #T_f67bc_row63_col2, #T_f67bc_row66_col2, #T_f67bc_row67_col2, #T_f67bc_row68_col2, #T_f67bc_row69_col2, #T_f67bc_row70_col2, #T_f67bc_row73_col2, #T_f67bc_row74_col2, #T_f67bc_row77_col2, #T_f67bc_row78_col2, #T_f67bc_row80_col2, #T_f67bc_row82_col2, #T_f67bc_row84_col2, #T_f67bc_row86_col2, #T_f67bc_row87_col2, #T_f67bc_row88_col2, #T_f67bc_row89_col2, #T_f67bc_row90_col2, #T_f67bc_row91_col2, #T_f67bc_row92_col2, #T_f67bc_row94_col2, #T_f67bc_row95_col2, #T_f67bc_row96_col2, #T_f67bc_row97_col2, #T_f67bc_row98_col2, #T_f67bc_row99_col2, #T_f67bc_row100_col2, #T_f67bc_row102_col2, #T_f67bc_row103_col2, #T_f67bc_row104_col2, #T_f67bc_row105_col2, #T_f67bc_row108_col2, #T_f67bc_row109_col2, #T_f67bc_row111_col2, #T_f67bc_row112_col2, #T_f67bc_row113_col2, #T_f67bc_row115_col2, #T_f67bc_row116_col2, #T_f67bc_row117_col2, #T_f67bc_row118_col2, #T_f67bc_row119_col2, #T_f67bc_row122_col2, #T_f67bc_row123_col2, #T_f67bc_row126_col2, #T_f67bc_row127_col2, #T_f67bc_row128_col2, #T_f67bc_row130_col2, #T_f67bc_row131_col2, #T_f67bc_row134_col2, #T_f67bc_row135_col2, #T_f67bc_row136_col2, #T_f67bc_row138_col2, #T_f67bc_row139_col2, #T_f67bc_row141_col2, #T_f67bc_row142_col2, #T_f67bc_row143_col2, #T_f67bc_row145_col2, #T_f67bc_row146_col2, #T_f67bc_row151_col2, #T_f67bc_row153_col2, #T_f67bc_row154_col2, #T_f67bc_row155_col2, #T_f67bc_row157_col2, #T_f67bc_row158_col2, #T_f67bc_row159_col2, #T_f67bc_row161_col2, #T_f67bc_row163_col2, #T_f67bc_row165_col2, #T_f67bc_row167_col2, #T_f67bc_row168_col2, #T_f67bc_row170_col2, #T_f67bc_row172_col2, #T_f67bc_row174_col2, #T_f67bc_row176_col2, #T_f67bc_row178_col2, #T_f67bc_row179_col2, #T_f67bc_row182_col2, #T_f67bc_row183_col2, #T_f67bc_row184_col2, #T_f67bc_row186_col2, #T_f67bc_row187_col2, #T_f67bc_row188_col2, #T_f67bc_row191_col2, #T_f67bc_row192_col2, #T_f67bc_row193_col2, #T_f67bc_row194_col2, #T_f67bc_row196_col2, #T_f67bc_row199_col2, #T_f67bc_row200_col2, #T_f67bc_row202_col2, #T_f67bc_row204_col2, #T_f67bc_row205_col2, #T_f67bc_row206_col2, #T_f67bc_row207_col1, #T_f67bc_row207_col3, #T_f67bc_row207_col4, #T_f67bc_row207_col5, #T_f67bc_row208_col1, #T_f67bc_row208_col3, #T_f67bc_row208_col4, #T_f67bc_row208_col5, #T_f67bc_row209_col1, #T_f67bc_row209_col3, #T_f67bc_row209_col4, #T_f67bc_row209_col5, #T_f67bc_row210_col1, #T_f67bc_row210_col3, #T_f67bc_row210_col4, #T_f67bc_row210_col5, #T_f67bc_row211_col1, #T_f67bc_row211_col3, #T_f67bc_row211_col4, #T_f67bc_row211_col5, #T_f67bc_row212_col1, #T_f67bc_row212_col3, #T_f67bc_row212_col4, #T_f67bc_row212_col5, #T_f67bc_row213_col1, #T_f67bc_row213_col3, #T_f67bc_row213_col4, #T_f67bc_row213_col5, #T_f67bc_row214_col1, #T_f67bc_row214_col3, #T_f67bc_row214_col4, #T_f67bc_row214_col5, #T_f67bc_row215_col1, #T_f67bc_row215_col3, #T_f67bc_row215_col4, #T_f67bc_row215_col5, #T_f67bc_row216_col1, #T_f67bc_row216_col3, #T_f67bc_row216_col4, #T_f67bc_row216_col5, #T_f67bc_row217_col1, #T_f67bc_row217_col3, #T_f67bc_row217_col4, #T_f67bc_row217_col5, #T_f67bc_row218_col1, #T_f67bc_row218_col3, #T_f67bc_row218_col4, #T_f67bc_row218_col5, #T_f67bc_row219_col1, #T_f67bc_row219_col3, #T_f67bc_row219_col4, #T_f67bc_row219_col5, # ...
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_f67bc_row2_col1, #T_f67bc_row22_col7, #T_f67bc_row162_col6 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_f67bc_row2_col2, #T_f67bc_row58_col6 {
#   background-color: #187cb6;
#   color: #f1f1f1;
# }
# #T_f67bc_row2_col3, #T_f67bc_row121_col6 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_f67bc_row2_col4, #T_f67bc_row48_col7, #T_f67bc_row133_col2, #T_f67bc_row209_col6, #T_f67bc_row212_col6 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_f67bc_row2_col5, #T_f67bc_row36_col7, #T_f67bc_row118_col6 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_f67bc_row2_col6 {
#   bac

# %%
centrality_ranks = centrality_summary_haystack_df.rank(ascending=False, 
                                           numeric_only=True, 
                                           method="dense").astype(int)
centrality_ranks.insert(loc=0, column='node', value=centrality_summary_brick_df["node"])
centrality_ranks.sort_values("in_degree_centrality").style.background_gradient(subset=list(centrality_ranks.columns[1:]))
# Out:
# <style type="text/css">
# #T_d07fc_row0_col1, #T_d07fc_row0_col3, #T_d07fc_row0_col4, #T_d07fc_row0_col5, #T_d07fc_row1_col7, #T_d07fc_row14_col2, #T_d07fc_row15_col2, #T_d07fc_row16_col2, #T_d07fc_row17_col2, #T_d07fc_row18_col2, #T_d07fc_row19_col2, #T_d07fc_row20_col2, #T_d07fc_row21_col2, #T_d07fc_row22_col2, #T_d07fc_row23_col2, #T_d07fc_row24_col2, #T_d07fc_row25_col2, #T_d07fc_row26_col2, #T_d07fc_row33_col2, #T_d07fc_row42_col2, #T_d07fc_row53_col2, #T_d07fc_row61_col2, #T_d07fc_row65_col2, #T_d07fc_row66_col2, #T_d07fc_row67_col2, #T_d07fc_row71_col2, #T_d07fc_row73_col2, #T_d07fc_row79_col2, #T_d07fc_row80_col2, #T_d07fc_row84_col2, #T_d07fc_row87_col2, #T_d07fc_row89_col2, #T_d07fc_row94_col2, #T_d07fc_row95_col2, #T_d07fc_row96_col2, #T_d07fc_row97_col2, #T_d07fc_row100_col2, #T_d07fc_row102_col2, #T_d07fc_row104_col2, #T_d07fc_row105_col2, #T_d07fc_row106_col2, #T_d07fc_row107_col2, #T_d07fc_row109_col2, #T_d07fc_row111_col2, #T_d07fc_row113_col2, #T_d07fc_row114_col2, #T_d07fc_row118_col2, #T_d07fc_row119_col2, #T_d07fc_row120_col2, #T_d07fc_row121_col2, #T_d07fc_row122_col2, #T_d07fc_row123_col2, #T_d07fc_row124_col2, #T_d07fc_row127_col2, #T_d07fc_row131_col2, #T_d07fc_row132_col2, #T_d07fc_row134_col2, #T_d07fc_row135_col2, #T_d07fc_row136_col2, #T_d07fc_row137_col2, #T_d07fc_row138_col2, #T_d07fc_row139_col2, #T_d07fc_row140_col2, #T_d07fc_row142_col2, #T_d07fc_row143_col2, #T_d07fc_row144_col2, #T_d07fc_row145_col2, #T_d07fc_row146_col2, #T_d07fc_row147_col2, #T_d07fc_row149_col2, #T_d07fc_row152_col2, #T_d07fc_row153_col2, #T_d07fc_row155_col2, #T_d07fc_row156_col2, #T_d07fc_row158_col2, #T_d07fc_row161_col2, #T_d07fc_row162_col2, #T_d07fc_row164_col2, #T_d07fc_row165_col2, #T_d07fc_row166_col2, #T_d07fc_row168_col2, #T_d07fc_row169_col2, #T_d07fc_row169_col6, #T_d07fc_row171_col2, #T_d07fc_row172_col2, #T_d07fc_row174_col2, #T_d07fc_row175_col2, #T_d07fc_row176_col2, #T_d07fc_row177_col2, #T_d07fc_row179_col2, #T_d07fc_row180_col2, #T_d07fc_row182_col2, #T_d07fc_row183_col2, #T_d07fc_row184_col2, #T_d07fc_row185_col2, #T_d07fc_row186_col2, #T_d07fc_row187_col2, #T_d07fc_row188_col2, #T_d07fc_row189_col2, #T_d07fc_row190_col2, #T_d07fc_row191_col2, #T_d07fc_row192_col2, #T_d07fc_row193_col2, #T_d07fc_row195_col2, #T_d07fc_row196_col2, #T_d07fc_row197_col2, #T_d07fc_row198_col2, #T_d07fc_row199_col2, #T_d07fc_row200_col2, #T_d07fc_row201_col2, #T_d07fc_row201_col6, #T_d07fc_row205_col2, #T_d07fc_row206_col2, #T_d07fc_row207_col2, #T_d07fc_row208_col2, #T_d07fc_row210_col2, #T_d07fc_row211_col2, #T_d07fc_row212_col2, #T_d07fc_row213_col2, #T_d07fc_row215_col2, #T_d07fc_row217_col2, #T_d07fc_row220_col2, #T_d07fc_row221_col2, #T_d07fc_row222_col2, #T_d07fc_row223_col2, #T_d07fc_row224_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_d07fc_row0_col2, #T_d07fc_row17_col7, #T_d07fc_row90_col1, #T_d07fc_row90_col3, #T_d07fc_row90_col4, #T_d07fc_row90_col5, #T_d07fc_row91_col1, #T_d07fc_row91_col3, #T_d07fc_row91_col4, #T_d07fc_row91_col5, #T_d07fc_row92_col1, #T_d07fc_row92_col3, #T_d07fc_row92_col4, #T_d07fc_row92_col5, #T_d07fc_row93_col1, #T_d07fc_row93_col3, #T_d07fc_row93_col4, #T_d07fc_row93_col5, #T_d07fc_row94_col1, #T_d07fc_row94_col3, #T_d07fc_row94_col4, #T_d07fc_row94_col5, #T_d07fc_row95_col1, #T_d07fc_row95_col3, #T_d07fc_row95_col4, #T_d07fc_row95_col5, #T_d07fc_row96_col1, #T_d07fc_row96_col3, #T_d07fc_row96_col4, #T_d07fc_row96_col5, #T_d07fc_row97_col1, #T_d07fc_row97_col3, #T_d07fc_row97_col4, #T_d07fc_row97_col5, #T_d07fc_row98_col1, #T_d07fc_row98_col3, #T_d07fc_row98_col4, #T_d07fc_row98_col5, #T_d07fc_row99_col1, #T_d07fc_row99_col3, #T_d07fc_row99_col4, #T_d07fc_row99_col5, #T_d07fc_row100_col1, #T_d07fc_row100_col3, #T_d07fc_row100_col4, #T_d07fc_row100_col5, #T_d07fc_row101_col1, #T_d07fc_row101_col3, #T_d07fc_row101_col4, #T_d07fc_row101_col5, #T_d07fc_row102_col1, #T_d07fc_row102_col3, #T_d07fc_row102_col4, #T_d07fc_row102_col5, #T_d07fc_row103_col1, #T_d07fc_row103_col3, #T_d07fc_row103_col4, #T_d07fc_row103_col5, #T_d07fc_row104_col1, #T_d07fc_row104_col3, #T_d07fc_row104_col4, #T_d07fc_row104_col5, #T_d07fc_row105_col1, #T_d07fc_row105_col3, #T_d07fc_row105_col4, #T_d07fc_row105_col5, #T_d07fc_row106_col1, #T_d07fc_row106_col3, #T_d07fc_row106_col4, #T_d07fc_row106_col5, #T_d07fc_row107_col1, #T_d07fc_row107_col3, #T_d07fc_row107_col4, #T_d07fc_row107_col5, #T_d07fc_row108_col1, #T_d07fc_row108_col3, #T_d07fc_row108_col4, #T_d07fc_row108_col5, #T_d07fc_row109_col1, #T_d07fc_row109_col3, #T_d07fc_row109_col4, #T_d07fc_row109_col5, #T_d07fc_row109_col6, #T_d07fc_row110_col1, #T_d07fc_row110_col3, #T_d07fc_row110_col4, #T_d07fc_row110_col5, #T_d07fc_row111_col1, #T_d07fc_row111_col3, #T_d07fc_row111_col4, #T_d07fc_row111_col5, #T_d07fc_row112_col1, #T_d07fc_row112_col3, #T_d07fc_row112_col4, #T_d07fc_row112_col5, #T_d07fc_row113_col1, #T_d07fc_row113_col3, #T_d07fc_row113_col4, #T_d07fc_row113_col5, #T_d07fc_row114_col1, #T_d07fc_row114_col3, #T_d07fc_row114_col4, #T_d07fc_row114_col5, #T_d07fc_row115_col1, #T_d07fc_row115_col3, #T_d07fc_row115_col4, #T_d07fc_row115_col5, #T_d07fc_row116_col1, #T_d07fc_row116_col3, #T_d07fc_row116_col4, #T_d07fc_row116_col5, #T_d07fc_row117_col1, #T_d07fc_row117_col3, #T_d07fc_row117_col4, #T_d07fc_row117_col5, #T_d07fc_row118_col1, #T_d07fc_row118_col3, #T_d07fc_row118_col4, #T_d07fc_row118_col5, #T_d07fc_row119_col1, #T_d07fc_row119_col3, #T_d07fc_row119_col4, #T_d07fc_row119_col5, #T_d07fc_row120_col1, #T_d07fc_row120_col3, #T_d07fc_row120_col4, #T_d07fc_row120_col5, #T_d07fc_row121_col1, #T_d07fc_row121_col3, #T_d07fc_row121_col4, #T_d07fc_row121_col5, #T_d07fc_row122_col1, #T_d07fc_row122_col3, #T_d07fc_row122_col4, #T_d07fc_row122_col5, #T_d07fc_row123_col1, #T_d07fc_row123_col3, #T_d07fc_row123_col4, #T_d07fc_row123_col5, #T_d07fc_row124_col1, #T_d07fc_row124_col3, #T_d07fc_row124_col4, #T_d07fc_row124_col5, #T_d07fc_row125_col1, #T_d07fc_row125_col3, #T_d07fc_row125_col4, #T_d07fc_row125_col5, #T_d07fc_row126_col1, #T_d07fc_row126_col3, #T_d07fc_row126_col4, #T_d07fc_row126_col5, #T_d07fc_row127_col1, #T_d07fc_row127_col3, #T_d07fc_row127_col4, #T_d07fc_row127_col5, #T_d07fc_row128_col1, #T_d07fc_row128_col3, #T_d07fc_row128_col4, #T_d07fc_row128_col5, #T_d07fc_row129_col1, #T_d07fc_row129_col3, #T_d07fc_row129_col4, #T_d07fc_row129_col5, #T_d07fc_row130_col1, #T_d07fc_row130_col3, #T_d07fc_row130_col4, #T_d07fc_row130_col5, #T_d07fc_row131_col1, #T_d07fc_row131_col3, #T_d07fc_row131_col4, #T_d07fc_row131_col5, #T_d07fc_row132_col1, #T_d07fc_row132_col3, #T_d07fc_row132_col4, #T_d07fc_row132_col5, #T_d07fc_row133_col1, #T_d07fc_row133_col3, #T_d07fc_row133_col4, #T_d07fc_row133_col5, #T_d07fc_row134_col1, #T_d07fc_row134_col3, #T_d07fc_row134_col4, #T_d07fc_row134_col5, #T_d07fc_row135_c ...

# %%
from openpyxl import Workbook

with pd.ExcelWriter('pandas_to_excel.xlsx') as writer:
    centrality_ranks.to_excel(writer, sheet_name='sheet1')

# %%
# compute the average ranking using the above ranks
average_ranks = pd.DataFrame(round(centrality_ranks.mean(axis=1)).astype(int), columns=["average_rank"])
average_ranks.insert(loc=0, column='node', value=centrality_summary_brick_df["node"])
average_ranks.sort_values("average_rank").reset_index(drop=True)\
    .style.background_gradient(subset=["average_rank"])
# Out:
# E:\JetBrains\PycharmProjects\BuildingOntologyAnalysis\venv\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# <style type="text/css">
# #T_69672_row0_col1 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_69672_row1_col1 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_69672_row2_col1, #T_69672_row3_col1 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_69672_row4_col1, #T_69672_row5_col1, #T_69672_row6_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_69672_row7_col1 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_69672_row8_col1 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_69672_row9_col1, #T_69672_row10_col1, #T_69672_row11_col1, #T_69672_row12_col1, #T_69672_row13_col1 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_69672_row14_col1, #T_69672_row15_col1, #T_69672_row16_col1, #T_69672_row17_col1, #T_69672_row18_col1, #T_69672_row19_col1, #T_69672_row20_col1, #T_69672_row21_col1, #T_69672_row22_col1, #T_69672_row23_col1, #T_69672_row24_col1, #T_69672_row25_col1 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_69672_row26_col1, #T_69672_row27_col1, #T_69672_row28_col1, #T_69672_row29_col1, #T_69672_row30_col1, #T_69672_row31_col1 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_69672_row32_col1, #T_69672_row33_col1, #T_69672_row34_col1, #T_69672_row35_col1, #T_69672_row36_col1, #T_69672_row37_col1 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_69672_row38_col1, #T_69672_row39_col1, #T_69672_row40_col1 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_69672_row41_col1, #T_69672_row42_col1, #T_69672_row43_col1, #T_69672_row44_col1, #T_69672_row45_col1, #T_69672_row46_col1, #T_69672_row47_col1, #T_69672_row48_col1, #T_69672_row49_col1, #T_69672_row50_col1, #T_69672_row51_col1, #T_69672_row52_col1, #T_69672_row53_col1, #T_69672_row54_col1, #T_69672_row55_col1, #T_69672_row56_col1, #T_69672_row57_col1, #T_69672_row58_col1, #T_69672_row59_col1, #T_69672_row60_col1, #T_69672_row61_col1, #T_69672_row62_col1, #T_69672_row63_col1, #T_69672_row64_col1, #T_69672_row65_col1, #T_69672_row66_col1, #T_69672_row67_col1, #T_69672_row68_col1, #T_69672_row69_col1, #T_69672_row70_col1, #T_69672_row71_col1, #T_69672_row72_col1, #T_69672_row73_col1, #T_69672_row74_col1, #T_69672_row75_col1, #T_69672_row76_col1, #T_69672_row77_col1, #T_69672_row78_col1, #T_69672_row79_col1, #T_69672_row80_col1, #T_69672_row81_col1, #T_69672_row82_col1, #T_69672_row83_col1, #T_69672_row84_col1, #T_69672_row85_col1, #T_69672_row86_col1 {
#   background-color: #b4c4df;
#   color: #000000;
# }
# #T_69672_row87_col1, #T_69672_row88_col1, #T_69672_row89_col1, #T_69672_row90_col1, #T_69672_row91_col1, #T_69672_row92_col1, #T_69672_row93_col1, #T_69672_row94_col1, #T_69672_row95_col1, #T_69672_row96_col1, #T_69672_row97_col1, #T_69672_row98_col1, #T_69672_row99_col1, #T_69672_row100_col1, #T_69672_row101_col1, #T_69672_row102_col1 {
#   background-color: #abbfdc;
#   color: #000000;
# }
# #T_69672_row103_col1 {
#   background-color: #a1bbda;
#   color: #000000;
# }
# #T_69672_row104_col1 {
#   background-color: #8bb2d4;
#   color: #000000;
# }
# #T_69672_row105_col1, #T_69672_row106_col1, #T_69672_row107_col1, #T_69672_row108_col1 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_69672_row109_col1 {
#   background-color: #73a9cf;
#   color: #f1f1f1;
# }
# #T_69672_row110_col1, #T_69672_row111_col1, #T_69672_row112_col1, #T_69672_row113_col1 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_69672_row114_col1, #T_69672_row115_col1, #T_69672_row116_col1, #T_69672_row117_col1, #T_69672_row118_col1, #T_69672_row119_col1, #T_69672_row120_col1, #T_69672_row121_col1, #T_69672_row122_col1 {
#   background-color: #589ec8;
#   color: #f1f1f1;
# }
# #T_69672_row123_col1, #T_69672_row124_col1, #T_69672_row125_col1, #T_69672_row126_col1, #T_69672_row127_col1, #T_69672_row128_col1 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_69672_row129_col1, #T_69672_row130_col1, #T_69672_row131_col1, #T_69672_row132_col1, #T_69672_row133_col1, #T_69672_row134_col1 {
#   background-color: #3d93c2;
#   color: #f1f1f1;
# }
# #T_69672_row135_col1, #T_69672_row136_col1, #T_69672_row137_col1, #T_69672_row138_col1, #T_69672_row139_col1, #T_69672_row140_col1, #T_69672_row141_col1 {
#   background-color: #308cbe;
#   color: #f1f1f1;
# }
# #T_69672_row142_col1, #T_69672_row143_col1, #T_69672_row144_col1, #T_69672_row145_col1, #T_69672_row146_col1, #T_69672_row147_col1, #T_69672_row148_col1 {
#   background-color: #2685bb;
#   color: #f1f1f1;
# }
# #T_69672_row149_col1, #T_69672_row150_col1, #T_69672_row151_col1, #T_69672_row152_col1, #T_69672_row153_col1, #T_69672_row154_col1, #T_69672_row155_col1, #T_69672_row156_col1, #T_69672_row157_col1 {
#   background-color: #1b7eb7;
#   color: #f1f1f1;
# }
# #T_69672_row158_col1, #T_69672_row159_col1, #T_69672_row160_col1, #T_69672_row161_col1 {
#   background-color: #1077b4;
#   color: #f1f1f1;
# }
# #T_69672_row162_col1, #T_69672_row163_col1, #T_69672_row164_col1, #T_69672_row165_col1, #T_69672_row166_col1 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_69672_row167_col1, #T_69672_row168_col1, #T_69672_row169_col1, #T_69672_row170_col1, #T_69672_row171_col1, #T_69672_row172_col1, #T_69672_row173_col1, #T_69672_row174_col1, #T_69672_row175_col1, #T_69672_row176_col1, #T_69672_row177_col1 {
#   background-color: #056ba7;
#   color: #f1f1f1;
# }
# #T_69672_row178_col1, #T_69672_row179_col1, #T_69672_row180_col1, #T_69672_row181_col1, #T_69672_row182_col1 {
#   background-color: #0566a0;
#   color: #f1f1f1;
# }
# #T_69672_row183_col1, #T_69672_row184_col1 {
#   background-color: #046198;
#   color: #f1f1f1;
# }
# #T_69672_row185_col1, #T_69672_row186_col1, #T_69672_row187_col1, #T_69672_row188_col1, #T_69672_row189_col1, #T_69672_row190_col1 {
#   background-color: #045c90;
#   color: #f1f1f1;
# }
# #T_69672_row191_col1, #T_69672_row192_col1, #T_69672_row193_col1, #T_69672_row194_col1, #T_69672_row195_col1, #T_69672_row196_col1, #T_69672_row197_col1, #T_69672_row198_col1, #T_69672_row199_col1, #T_69672_row200_col1 {
#   background-color: #045687;
#   color: #f1f1f1;
# }
# #T_69672_row201_col1, #T_69672_row202_col1, #T_69672_row203_col1, #T_69672_row204_col1, #T_69672_row205_col1, #T_69672_row206_col1, #T_69672_row207_col1, #T_69672_row208_col1, #T_69672_row209_col1, #T_69672_row210_col1 {
#   background-color: #034e7b;
#   color: #f1f1f1;
# }
# #T_69672_row211_col1, #T_69672_row212_col1, #T_69672_row213_col1, #T_69672_row214_col1, #T_69672_row215_col1, #T_69672_row216_col1, #T_69672_row217_col1 {
#   background-color: #03476f;
#   color: #f1f1f1;
# }
# #T_69672_row218_col1, #T_69672_row219_col1, #T_69672_row220_col1, #T_69672_row221_col1, #T_69672_row222_col1, #T_69672_row223_col1, #T_69672_row224_col1 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_69672_row225_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_69672_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >node</th>
#       <th class="col_heading level0 col1" >average_rank</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_69672_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_69672_row0_col0" class="data row0 col0" >http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#FCU_F7_ReturnDamper</td>
#       <td id="T_69672_row0_col1" class="data row0 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_69672_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_69672_row1_col0" class="data row1 col0" >http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#FCU_G7</td>
#       <td id="T_69672_row1_col1" class="data row1 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_69672_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_69672_row2_col0" class="data row2 col0" >http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#AC_G5</td>
#       <td id="T_69672_row2_col1" class="data row2 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_69672_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_69672_row3_col0" class="data row3 col0" >http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Ba

# %%
df = pd.DataFrame(columns = ['node','in_degree_centrality','out_degree_centrality','closeness_centrality','betweenness_centrality','pagerank_centrality','hub_centrality','hub_centrality'])

centrality_summary_brick_sensor = centrality_summary_brick_df.loc[centrality_summary_brick_df.node.str.strip() 
                                == "http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Chiller1"]
centrality_summary_brick_sensor.style.background_gradient(cmap='Blues')
centrality_summary_haystack_sensor = centrality_summary_haystack_df.loc[centrality_summary_haystack_df.node.str.strip() 
                                == "http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Chiller1"]
centrality_summary_recore_sensor = centrality_summary_recore_df.loc[centrality_summary_recore_df.node.str.strip() 
                                == "http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#Chiller1"]
centrality_summary_digitalbuilding_sensor = centrality_summary_digitalbuilding_df.loc[centrality_summary_digitalbuilding_df.node.str.strip() 
                                == "http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Chiller1"]

df = pd.concat([centrality_summary_brick_sensor,centrality_summary_haystack_sensor,centrality_summary_recore_sensor,centrality_summary_digitalbuilding_sensor])
# df.style.background_gradient(subset=list(df.columns[1:]))
df
# Out:
#                                                                                                      node  \
# 11                       http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#Chiller1
# 218               http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#Chiller1
# 52                   http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#Chiller1
# 15   http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#Chiller1
#
#      in_degree_centrality  out_degree_centrality  closeness_centrality  \
# 11               0.036885               0.006148              0.066393
# 218              0.000000               0.008511              0.000000
# 52               0.037344               0.004149              0.072871
# 15               0.038462               0.004274              0.069231
#
#      betweenness_centrality  pagerank_centrality  hub_centrality  \
# 11                 0.001022             0.011156   -3.720981e-19
# 218                0.000000             0.001321    9.555058e-19
# 52                 0.000543             0.008593    2.002581e-19
# 15                 0.000494             0.011496    4.103745e-20
#
#      auth_centrality
# 11     -3.093011e-01
# 218     0.000000e+00
# 52      5.659384e-02
# 15      1.040206e-16

# %%
df = pd.DataFrame(columns = ['node','in_degree_centrality','out_degree_centrality','closeness_centrality','betweenness_centrality','pagerank_centrality','hub_centrality','hub_centrality'])

centrality_summary_brick_sensor = centrality_summary_brick_df.loc[centrality_summary_brick_df.node.str.strip() 
                                == "http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#G6"]
centrality_summary_brick_sensor.style.background_gradient(cmap='Blues')
centrality_summary_haystack_sensor = centrality_summary_haystack_df.loc[centrality_summary_haystack_df.node.str.strip() 
                                == "http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#G6"]
centrality_summary_recore_sensor = centrality_summary_recore_df.loc[centrality_summary_recore_df.node.str.strip() 
                                == "http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#G6"]
centrality_summary_digitalbuilding_sensor = centrality_summary_digitalbuilding_df.loc[centrality_summary_digitalbuilding_df.node.str.strip() 
                                == "http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#G6"]

df = pd.concat([centrality_summary_brick_sensor,centrality_summary_haystack_sensor,centrality_summary_recore_sensor,centrality_summary_digitalbuilding_sensor])
# df.style.background_gradient(subset=list(df.columns[1:]))
df
# Out:
#                                                                                                node  \
# 116                      http://design-pattern-instance-only.qzc438.com/Brick_1.2.1/C_B307_Brick#G6
# 87                http://design-pattern-instance-only.qzc438.com/ProjectHaystack/C_B307_Haystack#G6
# 120                  http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#G6
# 122  http://design-pattern-instance-only.qzc438.com/GoogleDigitalBuilding/C_B307_DigitalBuilding#G6
#
#      in_degree_centrality  out_degree_centrality  closeness_centrality  \
# 116              0.002049               0.006148              0.002049
# 87               0.004255               0.006383              0.008688
# 120              0.002075               0.006224              0.002075
# 122              0.002137               0.006410              0.002137
#
#      betweenness_centrality  pagerank_centrality  hub_centrality  \
# 116                0.000008             0.001509    2.810058e-17
# 87                 0.000152             0.002274    1.451505e-18
# 120                0.000009             0.001529    2.682069e-07
# 122                0.000009             0.001555   -3.264570e-19
#
#      auth_centrality
# 116     2.609358e-18
# 87      3.537099e-03
# 120     2.124296e-06
# 122    -4.308477e-18

# %%
print(centrality_summary_recore_df)
# Out:
#                                                                                                  node  \
# 0    http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_F1_OutsideDamper
# 1          http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_F2_HHWCoil
# 2          http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_B1_CHWCoil
# 3                  http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#Ground
# 4                   http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AC_F6
# ..                                                                                                ...
# 221          http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AC_G3_HtgVlv
# 222         http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AC_G6_HHWCoil
# 223   http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#AHU_G1_ReturnDamper
# 224                    http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#B2
# 225          http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#Level1_1.103
#
#      in_degree_centrality  out_degree_centrality  closeness_centrality  \
# 0                0.002075               0.004149              0.002075
# 1                0.004149               0.022822              0.004149
# 2                0.012448               0.006224              0.019450
# 3                0.002075               0.004149              0.006790
# 4                0.000000               0.018672              0.000000
# ..                    ...                    ...                   ...
# 221              0.002075               0.006224              0.002075
# 222              0.004149               0.006224              0.004149
# 223              0.002075               0.004149              0.002075
# 224              0.002075               0.006224              0.002075
# 225              0.002075               0.004149              0.002766
#
#      betweenness_centrality  pagerank_centrality  hub_centrality  \
# 0                  0.000006             0.001501    2.131111e-19
# 1                  0.000205             0.001820    6.067166e-02
# 2                  0.000211             0.002553    2.021205e-02
# 3                  0.000052             0.001695    3.167833e-19
# 4                  0.000000             0.001409    1.389401e-05
# ..                      ...                  ...             ...
# 221                0.000006             0.001529    3.153201e-04
# 222                0.000041             0.001853    2.399732e-02
# 223                0.000006             0.001501    5.089395e-19
# 224                0.000009             0.001509    2.754780e-07
# 225                0.000010             0.001494   -7.939863e-19
#
#      auth_centrality
# 0       1.994173e-06
# 1       5.104208e-05
# 2       4.795924e-02
# 3      -1.607535e-18
# 4       0.000000e+00
# ..               ...
# 221     2.124296e-06
# 222     5.117419e-05
# 223     1.994173e-06
# 224     2.198316e-06
# 225     1.113226e-08
#
# [226 rows x 8 columns]

# %%
centrality_summary_recore_df.loc[centrality_summary_recore_df.node.str.strip() 
                                == "http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#Level1_1.111"]
# Out:
#                                                                                          node  \
# 124  http://design-pattern-instance-only.qzc438.com/RealEstateCore/C_B307_RECore#Level1_1.111
#
#      in_degree_centrality  out_degree_centrality  closeness_centrality  \
# 124              0.002075               0.004149              0.002766
#
#      betweenness_centrality  pagerank_centrality  hub_centrality  \
# 124                0.000017             0.001494    3.393206e-19
#
#      auth_centrality
# 124     1.113226e-08
