# %%
from os import walk

dirpath = "Brick";
filenames = next(walk(dirpath), (None, None, []))[2]  # [] if no file
print(filenames)
# Out:
# ['ebu3b_brick.ttl', 'ghc_brick.ttl', 'gtc_brick.ttl', 'rice_brick.ttl', 'soda_brick.ttl']

# %%
from rdflib import Graph as RDFGraph
from rdflib.extras.external_graph_libs import rdflib_to_networkx_digraph

# loadn RDF Graph
dic = {}
for filename in filenames:
    print(filename)
    path = dirpath + "/" + filename
    g = RDFGraph()
    g.parse(path)
    print("rdflib Graph loaded successfully with {} triples".format(len(g)))
    G = rdflib_to_networkx_digraph(g)
    print("networkx Graph loaded successfully with length {}".format(len(G)))
    dic.update({str(filename):G})
# print (dic)
# Out:
# ebu3b_brick.ttl
# rdflib Graph loaded successfully with 14572 triples
# networkx Graph loaded successfully with length 6375
# ghc_brick.ttl
# rdflib Graph loaded successfully with 55733 triples
# networkx Graph loaded successfully with length 9874
# gtc_brick.ttl
# rdflib Graph loaded successfully with 8681 triples
# networkx Graph loaded successfully with length 2560
# rice_brick.ttl
# rdflib Graph loaded successfully with 1665 triples
# networkx Graph loaded successfully with length 810
# soda_brick.ttl
# rdflib Graph loaded successfully with 3774 triples
# networkx Graph loaded successfully with length 1739

# %%
# show complete node
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
number_of_nodes = {}
for k, v in dic.items():
    v = v.number_of_nodes()
    number_of_nodes.update({k:v})

number_of_nodes_df = pd.DataFrame(data = number_of_nodes,index=[0])
number_of_nodes_df.head(10)
# Out:
#    ebu3b_brick.ttl  ghc_brick.ttl  gtc_brick.ttl  rice_brick.ttl  \
# 0             6375           9874           2560             810
#
#    soda_brick.ttl
# 0            1739

# %%
number_of_edges = {}
for k, v in dic.items():
    v = v.number_of_edges()
    number_of_edges.update ({k:v})

number_of_edges_df = pd.DataFrame(data = number_of_edges,index=[0])
number_of_edges_df.head(10)
# Out:
#    ebu3b_brick.ttl  ghc_brick.ttl  gtc_brick.ttl  rice_brick.ttl  \
# 0            14572          54783           8177            1484
#
#    soda_brick.ttl
# 0            3774

# %%
prefix_soda = "https://brickschema.org/schema/1.0.2/building_example#"
prefix_ghc = "http://cmu.edu/building/ontology/ghc#"
prefix_rice = "http://virginia.edu/building/ontology/rice#"
prefix_ebu = "http://ucsd.edu/building/ontology/ebu3b#"
prefix_gtc = "https://brickschema.org/schema/1.0.2/building_example#"
prefix = [prefix_soda, prefix_ghc, prefix_rice, prefix_ebu, prefix_gtc]

# %% [markdown]
# ### Dan's Paper (degree and class hierarchy/depth)

# %%
import networkx as nx

dan_summary_soda_df = pd.DataFrame()
dan_summary_ghc_df = pd.DataFrame()
dan_summary_rice_df = pd.DataFrame()
dan_summary_ebu_df = pd.DataFrame()
dan_summary_gtc_df = pd.DataFrame()

# %%
# number of degree
for k, v in dic.items():
    number_of_degree_df = pd.DataFrame(data = v.degree(), 
                                           columns = ["node", "number_of_degree"])
    # filter
    if k == "soda_brick.ttl":
        number_of_degree_df = number_of_degree_df[number_of_degree_df['node'].str.startswith(prefix_soda)]
        dan_summary_soda_df = number_of_degree_df
    if k == "ghc_brick.ttl":
        number_of_degree_df = number_of_degree_df[number_of_degree_df['node'].str.startswith(prefix_ghc)]
        dan_summary_ghc_df = number_of_degree_df
    if k == "rice_brick.ttl":
        number_of_degree_df = number_of_degree_df[number_of_degree_df['node'].str.startswith(prefix_rice)]
        dan_summary_rice_df = number_of_degree_df
    if k == "ebu3b_brick.ttl":
        number_of_degree_df = number_of_degree_df[number_of_degree_df['node'].str.startswith(prefix_ebu)]
        dan_summary_ebu_df = number_of_degree_df
    if k == "gtc_brick.ttl":
        number_of_degree_df = number_of_degree_df[number_of_degree_df['node'].str.startswith(prefix_gtc)]
        dan_summary_gtc_df = number_of_degree_df
        
    # sort
    number_of_degree_df = number_of_degree_df.sort_values("number_of_degree", ascending = False)
    # reset index
    number_of_degree_df = number_of_degree_df.reset_index(drop=True)
    
    # print
    print ("file:", k)
    print("data points", len(number_of_degree_df.index))
    print (number_of_degree_df.head(5))
    print ("====================================================================================================")
# Out:
# file: ebu3b_brick.ttl
# data points 6179
#                                                     node  number_of_degree
# 0    http://ucsd.edu/building/ontology/ebu3b#EBU3B_AHU_1               487
# 1  http://ucsd.edu/building/ontology/ebu3b#EBU3B_Floor_3                61
# 2  http://ucsd.edu/building/ontology/ebu3b#EBU3B_Floor_2                59
# 3  http://ucsd.edu/building/ontology/ebu3b#EBU3B_Floor_4                58
# 4  http://ucsd.edu/building/ontology/ebu3b#EBU3B_Floor_1                52
# ====================================================================================================
# file: ghc_brick.ttl
# data points 9681
#                                             node  number_of_degree
# 0  http://cmu.edu/building/ontology/ghc#AHU-12_I               225
# 1   http://cmu.edu/building/ontology/ghc#AHU-9_I               209
# 2  http://cmu.edu/building/ontology/ghc#AHU-10_I               194
# 3  http://cmu.edu/building/ontology/ghc#AHU-11_I               149
# 4   http://cmu.edu/building/ontology/ghc#AHU-8_I               130
# ====================================================================================================
# file: gtc_brick.ttl
# data points 1989
#                                                                                               node  \
# 0          https://brickschema.org/schema/1.0.2/building_example#Celcius_Room_Temperature_Setpoint
# 1                      https://brickschema.org/schema/1.0.2/building_example#LEDGO_Lighting_System
# 2         https://brickschema.org/schema/1.0.2/building_example#building:gtc/radiator_htb/port[so]
# 3  https://brickschema.org/schema/1.0.2/building_example#building:gtc/electrical/submeter[-A1.0.1]
# 4  https://brickschema.org/schema/1.0.2/building_example#building:gtc/electrical/main_common_meter
#
#    number_of_degree
# 0               340
# 1               250
# 2               231
# 3               220
# 4               173
# ====================================================================================================
# file: rice_brick.ttl
# data points 695
#                                                     node  number_of_degree
# 0        http://virginia.edu/building/ontology/rice#VAV2                40
# 1        http://virginia.edu/building/ontology/rice#VAV3                32
# 2  http://virginia.edu/building/ontology/rice#HVAC_Zone2                31
# 3     http://virginia.edu/building/ontology/rice#Floor_5                30
# 4        http://virginia.edu/building/ontology/rice#VAV1                26
# ====================================================================================================
# file: soda_brick.ttl
# data points 1698
#                                                             node  \
# 0   https://brickschema.org/schema/1.0.2/building_example#ahu_A1
# 1   https://brickschema.org/schema/1.0.2/building_example#ahu_A3
# 2   https://brickschema.org/schema/1.0.2/building_example#ahu_A4
# 3  https://brickschema.org/schema/1.0.2/building_example#floor_3
# 4  https://brickschema.org/schema/1.0.2/building_example#floor_5
#
#    number_of_degree
# 0               111
# 1                85
# 2                83
# 3                57
# 4                54
# ====================================================================================================

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x1 = dan_summary_soda_df.number_of_degree
x2 = dan_summary_ghc_df.number_of_degree
x3 = dan_summary_rice_df.number_of_degree
x4 = dan_summary_ebu_df.number_of_degree
x5 = dan_summary_gtc_df.number_of_degree
plt.boxplot ([x1,x2,x3,x4,x5])
plt.xticks([1,2,3,4,5], ['soda','ghc','rice','ebu', 'gtc'])
plt.title ("Number of Degrees (Original Model)")
plt.savefig('Number of Degrees-Original.jpg', bbox_inches='tight', dpi=500)

# %% [markdown]
# ### Centrality Analysis

# %% [markdown]
# ### 1. Heuristic (simple) centrality: Degree centrality (local importance)

# %%
import networkx as nx

centrality_summary_soda_df = pd.DataFrame()
centrality_summary_ghc_df = pd.DataFrame()
centrality_summary_rice_df = pd.DataFrame()
centrality_summary_ebu_df = pd.DataFrame()
centrality_summary_gtc_df = pd.DataFrame()

# %%
# in-degree centrality
for k, v in dic.items():
    in_degree_centrality_df = pd.DataFrame(data = nx.in_degree_centrality(v).items(), 
                                           columns = ["node", "in_degree_centrality"])
#     print (in_degree_centrality_df.head(10))
    # filter
    if k == "soda_brick.ttl":
        in_degree_centrality_df = in_degree_centrality_df[in_degree_centrality_df['node'].str.startswith(prefix_soda)]
        centrality_summary_soda_df = in_degree_centrality_df
    if k == "ghc_brick.ttl":
        in_degree_centrality_df = in_degree_centrality_df[in_degree_centrality_df['node'].str.startswith(prefix_ghc)]
        centrality_summary_ghc_df = in_degree_centrality_df
    if k == "rice_brick.ttl":
        in_degree_centrality_df = in_degree_centrality_df[in_degree_centrality_df['node'].str.startswith(prefix_rice)]
        centrality_summary_rice_df = in_degree_centrality_df
    if k == "ebu3b_brick.ttl":
        in_degree_centrality_df = in_degree_centrality_df[in_degree_centrality_df['node'].str.startswith(prefix_ebu)]
        centrality_summary_ebu_df = in_degree_centrality_df
    if k == "gtc_brick.ttl":
        in_degree_centrality_df = in_degree_centrality_df[in_degree_centrality_df['node'].str.startswith(prefix_gtc)]
        centrality_summary_gtc_df = in_degree_centrality_df
    
    # sort
    in_degree_centrality_df = in_degree_centrality_df.sort_values("in_degree_centrality", ascending = False)
    
    # print
    print (k)
    print (in_degree_centrality_df.head(10))
    print ("==================================================")
# Out:
# ebu3b_brick.ttl
#                                                        node  \
# 198     http://ucsd.edu/building/ontology/ebu3b#EBU3B_AHU_1
# 655   http://ucsd.edu/building/ontology/ebu3b#EBU3B_Floor_3
# 356   http://ucsd.edu/building/ontology/ebu3b#EBU3B_Floor_2
# 333   http://ucsd.edu/building/ontology/ebu3b#EBU3B_Floor_4
# 1137  http://ucsd.edu/building/ontology/ebu3b#EBU3B_Floor_1
# 96     http://ucsd.edu/building/ontology/ebu3b#EBU3B_CRAC_1
# 752    http://ucsd.edu/building/ontology/ebu3b#EBU3B_CRAC_4
# 737    http://ucsd.edu/building/ontology/ebu3b#EBU3B_CRAC_3
# 297    http://ucsd.edu/building/ontology/ebu3b#EBU3B_CRAC_2
# 791      http://ucsd.edu/building/ontology/ebu3b#EBU3B_HVAC
#
#       in_degree_centrality
# 198               0.038908
# 655               0.009256
# 356               0.008943
# 333               0.008786
# 1137              0.007844
# 96                0.007531
# 752               0.007531
# 737               0.007531
# 297               0.007531
# 791               0.005962
# ==================================================
# ghc_brick.ttl
#                                                  node  in_degree_centrality
# 333      http://cmu.edu/building/ontology/ghc#AHU-2_I              0.005672
# 897  http://cmu.edu/building/ontology/ghc#AHU-2_IRoom              0.005672
# 129      http://cmu.edu/building/ontology/ghc#AHU-4_I              0.005368
# 301      http://cmu.edu/building/ontology/ghc#AHU-7_I              0.005368
# 342      http://cmu.edu/building/ontology/ghc#AHU-3_I              0.005368
# 344  http://cmu.edu/building/ontology/ghc#AHU-3_IRoom              0.005368
# 98   http://cmu.edu/building/ontology/ghc#AHU-7_IRoom              0.005368
# 812  http://cmu.edu/building/ontology/ghc#AHU-4_IRoom              0.005368
# 55   http://cmu.edu/building/ontology/ghc#AHU-1_IRoom              0.005267
# 149      http://cmu.edu/building/ontology/ghc#AHU-1_I              0.005267
# ==================================================
# gtc_brick.ttl
#                                                                                                 node  \
# 95           https://brickschema.org/schema/1.0.2/building_example#Celcius_Room_Temperature_Setpoint
# 1                        https://brickschema.org/schema/1.0.2/building_example#LEDGO_Lighting_System
# 59   https://brickschema.org/schema/1.0.2/building_example#building:gtc/electrical/submeter[-A1.0.1]
# 306  https://brickschema.org/schema/1.0.2/building_example#building:gtc/electrical/main_common_meter
# 19   https://brickschema.org/schema/1.0.2/building_example#building:gtc/electrical/submeter[-A1.2.3]
# 34   https://brickschema.org/schema/1.0.2/building_example#building:gtc/electrical/submeter[-A1.2.2]
# 57   https://brickschema.org/schema/1.0.2/building_example#building:gtc/electrical/submeter[-A1.1.1]
# 86          https://brickschema.org/schema/1.0.2/building_example#building:gtc/radiator_htb/port[so]
# 181  https://brickschema.org/schema/1.0.2/building_example#building:gtc/electrical/submeter[-A1.2.4]
# 53   https://brickschema.org/schema/1.0.2/building_example#building:gtc/electrical/submeter[-A1.2.1]
#
#      in_degree_centrality
# 95               0.131301
# 1                0.097304
# 59               0.084799
# 306              0.066432
# 19               0.052755
# 34               0.046893
# 57               0.046112
# 86               0.044939
# 181              0.039078
# 53               0.039078
# ==================================================
# rice_brick.ttl
#                                                    node  in_degree_centrality
# 102     http://virginia.edu/building/ontology/rice#RICE              0.012361
# 55    http://virginia.edu/building/ontology/rice#Room32              0.004944
# 39     http://virginia.edu/building/ontology/rice#Room7              0.003708
# 63   http://virginia.edu/building/ontology/rice#Room102              0.003708
# 213  http://virginia.edu/building/ontology/rice#Room322              0.003708
# 33   http://virginia.edu/building/ontology/rice#Room203              0.003708
# 61   http://virginia.edu/building/ontology/rice#Room156              0.003708
# 37   http://virginia.edu/building/ontology/rice#Room209              0.003708
# 353  http://virginia.edu/building/ontology/rice#Room208              0.003708
# 133  http://virginia.edu/building/ontology/rice#Room106              0.003708
# ==================================================
# soda_brick.ttl
#                                                                                   node  \
# 29                       https://brickschema.org/schema/1.0.2/building_example#floor_3
# 174                      https://brickschema.org/schema/1.0.2/building_example#floor_5
# 9                        https://brickschema.org/schema/1.0.2/building_example#floor_4
# 133                      https://brickschema.org/schema/1.0.2/building_example#floor_6
# 77                       https://brickschema.org/schema/1.0.2/building_example#floor_7
# 437                      https://brickschema.org/schema/1.0.2/building_example#floor_2
# 148                      https://brickschema.org/schema/1.0.2/building_example#floor_1
# 486                   https://brickschema.org/schema/1.0.2/building_example#building_1
# 859                     https://brickschema.org/schema/1.0.2/building_example#vav_R369
# 1166  https://brickschema.org/schema/1.0.2/building_example#flow_sensor_hvac_zone_R798
#
#       in_degree_centrality
# 29                0.031646
# 174               0.029919
# 9                 0.026467
# 133               0.023590
# 77                0.020713
# 437               0.008055
# 148               0.006904
# 486               0.004028
# 859               0.001151
# 1166              0.000575
# ==================================================

# %%
# out-degree centrality
for k, v in dic.items():
    out_degree_centrality_df = pd.DataFrame(data = nx.out_degree_centrality(v).items(), 
                                           columns = ["node", "out_degree_centrality"])
    # filter
    if k == "soda_brick.ttl":
        out_degree_centrality_df = out_degree_centrality_df[out_degree_centrality_df['node'].str.startswith(prefix_soda)]
        centrality_summary_soda_df = centrality_summary_soda_df.merge(out_degree_centrality_df, on="node")
    if k == "ghc_brick.ttl":
        out_degree_centrality_df = out_degree_centrality_df[out_degree_centrality_df['node'].str.startswith(prefix_ghc)]
        centrality_summary_ghc_df = centrality_summary_ghc_df.merge(out_degree_centrality_df, on="node")
    if k == "rice_brick.ttl":
        out_degree_centrality_df = out_degree_centrality_df[out_degree_centrality_df['node'].str.startswith(prefix_rice)]
        centrality_summary_rice_df = centrality_summary_rice_df.merge(out_degree_centrality_df, on="node")
    if k == "ebu3b_brick.ttl":
        out_degree_centrality_df = out_degree_centrality_df[out_degree_centrality_df['node'].str.startswith(prefix_ebu)]
        centrality_summary_ebu_df = centrality_summary_ebu_df.merge(out_degree_centrality_df, on="node")
    if k == "gtc_brick.ttl":
        out_degree_centrality_df = out_degree_centrality_df[out_degree_centrality_df['node'].str.startswith(prefix_gtc)]
        centrality_summary_gtc_df = centrality_summary_gtc_df.merge(out_degree_centrality_df, on="node")
    
    # sort
    out_degree_centrality_df = out_degree_centrality_df.sort_values("out_degree_centrality", ascending = False)
    
    # print
    print (k)
    print (out_degree_centrality_df.head(10))
    print ("==================================================")
# Out:
# ebu3b_brick.ttl
#                                                                node  \
# 198             http://ucsd.edu/building/ontology/ebu3b#EBU3B_AHU_1
# 2965  http://ucsd.edu/building/ontology/ebu3b#EBU3B_RM_3258_W_C_ADJ
# 1141  http://ucsd.edu/building/ontology/ebu3b#EBU3B_RM_3109_W_C_ADJ
# 3002     http://ucsd.edu/building/ontology/ebu3b#EBU3B_RM_1145_ZN_T
# 5566     http://ucsd.edu/building/ontology/ebu3b#EBU3B_RM_2105_ZN_T
# 1105  http://ucsd.edu/building/ontology/ebu3b#EBU3B_RM_4226_W_C_ADJ
# 1114    http://ucsd.edu/building/ontology/ebu3b#EBU3B_RM_4232_T_OCC
# 1115  http://ucsd.edu/building/ontology/ebu3b#EBU3B_RM_4148_W_C_ADJ
# 4204     http://ucsd.edu/building/ontology/ebu3b#EBU3B_RM_2221_ZN_T
# 1124  http://ucsd.edu/building/ontology/ebu3b#EBU3B_RM_1116_W_C_ADJ
#
#       out_degree_centrality
# 198                0.037496
# 2965               0.000628
# 1141               0.000628
# 3002               0.000628
# 5566               0.000628
# 1105               0.000628
# 1114               0.000628
# 1115               0.000628
# 4204               0.000628
# 1124               0.000628
# ==================================================
# ghc_brick.ttl
#                                                  node  out_degree_centrality
# 303     http://cmu.edu/building/ontology/ghc#AHU-12_I               0.017624
# 864      http://cmu.edu/building/ontology/ghc#AHU-9_I               0.016003
# 226     http://cmu.edu/building/ontology/ghc#AHU-10_I               0.014484
# 592     http://cmu.edu/building/ontology/ghc#AHU-11_I               0.009926
# 577      http://cmu.edu/building/ontology/ghc#AHU-8_I               0.009420
# 129      http://cmu.edu/building/ontology/ghc#AHU-4_I               0.006584
# 301      http://cmu.edu/building/ontology/ghc#AHU-7_I               0.006077
# 342      http://cmu.edu/building/ontology/ghc#AHU-3_I               0.005875
# 333      http://cmu.edu/building/ontology/ghc#AHU-2_I               0.005875
# 897  http://cmu.edu/building/ontology/ghc#AHU-2_IRoom               0.005672
# ==================================================
# gtc_brick.ttl
#                                                                                          node  \
# 86   https://brickschema.org/schema/1.0.2/building_example#building:gtc/radiator_htb/port[so]
# 174                    https://brickschema.org/schema/1.0.2/building_example#building:gtc/ahu
# 292        https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/5/port[zn]
# 7          https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/1/port[zn]
# 833       https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/10/port[zn]
# 494        https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/7/port[zn]
# 167       https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/11/port[zn]
# 69         https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/8/port[zn]
# 793        https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/9/port[zn]
# 243        https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/4/port[zn]
#
#      out_degree_centrality
# 86                0.045330
# 174               0.012114
# 292               0.008597
# 7                 0.008597
# 833               0.008597
# 494               0.007816
# 167               0.007816
# 69                0.007425
# 793               0.007425
# 243               0.007425
# ==================================================
# rice_brick.ttl
#                                                       node  \
# 51         http://virginia.edu/building/ontology/rice#VAV2
# 75         http://virginia.edu/building/ontology/rice#VAV3
# 35   http://virginia.edu/building/ontology/rice#HVAC_Zone2
# 65      http://virginia.edu/building/ontology/rice#Floor_5
# 32      http://virginia.edu/building/ontology/rice#Floor_2
# 15         http://virginia.edu/building/ontology/rice#VAV1
# 289  http://virginia.edu/building/ontology/rice#HVAC_Zone1
# 186        http://virginia.edu/building/ontology/rice#VAV4
# 0    http://virginia.edu/building/ontology/rice#HVAC_Zone3
# 60      http://virginia.edu/building/ontology/rice#Floor_1
#
#      out_degree_centrality
# 51                0.048208
# 75                0.038319
# 35                0.037083
# 65                0.037083
# 32                0.030902
# 15                0.030902
# 289               0.028430
# 186               0.028430
# 0                 0.025958
# 60                0.024722
# ==================================================
# soda_brick.ttl
#                                                                      node  \
# 16           https://brickschema.org/schema/1.0.2/building_example#ahu_A1
# 22           https://brickschema.org/schema/1.0.2/building_example#ahu_A3
# 114          https://brickschema.org/schema/1.0.2/building_example#ahu_A4
# 154  https://brickschema.org/schema/1.0.2/building_example#supply_fan_S11
# 44   https://brickschema.org/schema/1.0.2/building_example#supply_fan_S16
# 111  https://brickschema.org/schema/1.0.2/building_example#supply_fan_S18
# 32   https://brickschema.org/schema/1.0.2/building_example#supply_fan_S14
# 347          https://brickschema.org/schema/1.0.2/building_example#ahu_A2
# 445        https://brickschema.org/schema/1.0.2/building_example#vav_R535
# 894        https://brickschema.org/schema/1.0.2/building_example#vav_R617
#
#      out_degree_centrality
# 16                0.063867
# 22                0.048907
# 114               0.047756
# 154               0.009206
# 44                0.009206
# 111               0.008055
# 32                0.005754
# 347               0.004603
# 445               0.004028
# 894               0.004028
# ==================================================

# %% [markdown]
# ## 2. Graphical centrality

# %% [markdown]
# ### (1) Closeness centrality (path spread importance)

# %%
# closeness centrality
for k, v in dic.items():
    closeness_centrality_df = pd.DataFrame(data = nx.closeness_centrality(v).items(), 
                                           columns = ["node", "closeness_centrality"])
    # filter
    if k == "soda_brick.ttl":
        closeness_centrality_df = closeness_centrality_df[closeness_centrality_df['node'].str.startswith(prefix_soda)]
        centrality_summary_soda_df = centrality_summary_soda_df.merge(closeness_centrality_df, on="node")
    if k == "ghc_brick.ttl":
        closeness_centrality_df = closeness_centrality_df[closeness_centrality_df['node'].str.startswith(prefix_ghc)]
        centrality_summary_ghc_df = centrality_summary_ghc_df.merge(closeness_centrality_df, on="node")
    if k == "rice_brick.ttl":
        closeness_centrality_df = closeness_centrality_df[closeness_centrality_df['node'].str.startswith(prefix_rice)]
        centrality_summary_rice_df = centrality_summary_rice_df.merge(closeness_centrality_df, on="node")
    if k == "ebu3b_brick.ttl":
        closeness_centrality_df = closeness_centrality_df[closeness_centrality_df['node'].str.startswith(prefix_ebu)]
        centrality_summary_ebu_df = centrality_summary_ebu_df.merge(closeness_centrality_df, on="node")
    if k == "gtc_brick.ttl":
        closeness_centrality_df = closeness_centrality_df[closeness_centrality_df['node'].str.startswith(prefix_gtc)]
        centrality_summary_gtc_df = centrality_summary_gtc_df.merge(closeness_centrality_df, on="node")
    
    # sort
    closeness_centrality_df = closeness_centrality_df.sort_values("closeness_centrality", ascending = False)
    
    # print
    print (k)
    print (closeness_centrality_df.head(10))
    print ("==================================================")
# Out:
# ebu3b_brick.ttl
#                                                            node  \
# 3650              http://ucsd.edu/building/ontology/ebu3b#EBU3B
# 655       http://ucsd.edu/building/ontology/ebu3b#EBU3B_Floor_3
# 356       http://ucsd.edu/building/ontology/ebu3b#EBU3B_Floor_2
# 333       http://ucsd.edu/building/ontology/ebu3b#EBU3B_Floor_4
# 1137      http://ucsd.edu/building/ontology/ebu3b#EBU3B_Floor_1
# 198         http://ucsd.edu/building/ontology/ebu3b#EBU3B_AHU_1
# 632      http://ucsd.edu/building/ontology/ebu3b#EBU3B_Basement
# 1821  http://ucsd.edu/building/ontology/ebu3b#EBU3B_VAV_Rm_B210
# 464   http://ucsd.edu/building/ontology/ebu3b#EBU3B_VAV_Rm_B230
# 1156  http://ucsd.edu/building/ontology/ebu3b#EBU3B_VAV_Rm_B250
#
#       closeness_centrality
# 3650              0.231444
# 655               0.081178
# 356               0.080109
# 333               0.079482
# 1137              0.070198
# 198               0.038124
# 632               0.037282
# 1821              0.023181
# 464               0.023063
# 1156              0.023063
# ==================================================
# ghc_brick.ttl
#                                                  node  closeness_centrality
# 897  http://cmu.edu/building/ontology/ghc#AHU-2_IRoom              0.005674
# 333      http://cmu.edu/building/ontology/ghc#AHU-2_I              0.005674
# 301      http://cmu.edu/building/ontology/ghc#AHU-7_I              0.005370
# 129      http://cmu.edu/building/ontology/ghc#AHU-4_I              0.005370
# 342      http://cmu.edu/building/ontology/ghc#AHU-3_I              0.005370
# 344  http://cmu.edu/building/ontology/ghc#AHU-3_IRoom              0.005370
# 98   http://cmu.edu/building/ontology/ghc#AHU-7_IRoom              0.005370
# 812  http://cmu.edu/building/ontology/ghc#AHU-4_IRoom              0.005370
# 55   http://cmu.edu/building/ontology/ghc#AHU-1_IRoom              0.005269
# 149      http://cmu.edu/building/ontology/ghc#AHU-1_I              0.005269
# ==================================================
# gtc_brick.ttl
#                                                                                                  node  \
# 133                     https://brickschema.org/schema/1.0.2/building_example#Electrical_Energy_Meter
# 95            https://brickschema.org/schema/1.0.2/building_example#Celcius_Room_Temperature_Setpoint
# 145                            https://brickschema.org/schema/1.0.2/building_example#Override_Command
# 406                                https://brickschema.org/schema/1.0.2/building_example#building:gtc
# 386             https://brickschema.org/schema/1.0.2/building_example#Celcius_Room_Temperature_Sensor
# 306   https://brickschema.org/schema/1.0.2/building_example#building:gtc/electrical/main_common_meter
# 934                    https://brickschema.org/schema/1.0.2/building_example#GTC_VAV_Downstream_Input
# 423                 https://brickschema.org/schema/1.0.2/building_example#building:gtc/wind_direction
# 1960                    https://brickschema.org/schema/1.0.2/building_example#building:gtc/wind_speed
# 1508                                       https://brickschema.org/schema/1.0.2/building_example#Fuse
#
#       closeness_centrality
# 133               0.230784
# 95                0.196370
# 145               0.183552
# 406               0.176887
# 386               0.172291
# 306               0.163630
# 934               0.138121
# 423               0.137670
# 1960              0.137670
# 1508              0.127237
# ==================================================
# rice_brick.ttl
#                                                                node  \
# 102                 http://virginia.edu/building/ontology/rice#RICE
# 55                http://virginia.edu/building/ontology/rice#Room32
# 539  http://virginia.edu/building/ontology/rice#Zone_Temp_4_RMI032B
# 56    http://virginia.edu/building/ontology/rice#Zone_Temp_2_RMI032
# 129  http://virginia.edu/building/ontology/rice#Zone_Temp_3_RMI032A
# 375              http://virginia.edu/building/ontology/rice#Room252
# 49               http://virginia.edu/building/ontology/rice#Room205
# 39                 http://virginia.edu/building/ontology/rice#Room7
# 223              http://virginia.edu/building/ontology/rice#Room552
# 198              http://virginia.edu/building/ontology/rice#Room154
#
#      closeness_centrality
# 102              0.012361
# 55               0.006506
# 539              0.005753
# 56               0.005753
# 129              0.005753
# 375              0.004659
# 49               0.004659
# 39               0.004659
# 223              0.004659
# 198              0.004659
# ==================================================
# soda_brick.ttl
#                                                                                     node  \
# 486                     https://brickschema.org/schema/1.0.2/building_example#building_1
# 29                         https://brickschema.org/schema/1.0.2/building_example#floor_3
# 174                        https://brickschema.org/schema/1.0.2/building_example#floor_5
# 9                          https://brickschema.org/schema/1.0.2/building_example#floor_4
# 133                        https://brickschema.org/schema/1.0.2/building_example#floor_6
# 77                         https://brickschema.org/schema/1.0.2/building_example#floor_7
# 437                        https://brickschema.org/schema/1.0.2/building_example#floor_2
# 148                        https://brickschema.org/schema/1.0.2/building_example#floor_1
# 859                       https://brickschema.org/schema/1.0.2/building_example#vav_R369
# 1522  https://brickschema.org/schema/1.0.2/building_example#reheat_sensor_hvac_zone_R369
#
#       closeness_centrality
# 486               0.145007
# 29                0.046185
# 174               0.043589
# 9                 0.038411
# 133               0.035406
# 77                0.031093
# 437               0.010790
# 148               0.009064
# 859               0.001151
# 1522              0.001036
# ==================================================

# %% [markdown]
# ### (2) Betweenness centrality (In-between/broker/bridge/middleman importance)

# %%
# betweenness centrality
for k, v in dic.items():
    betweenness_centrality_df = pd.DataFrame(data = nx.betweenness_centrality(v).items(), 
                                           columns = ["node", "betweenness_centrality"])
    # filter
    if k == "soda_brick.ttl":
        betweenness_centrality_df = betweenness_centrality_df[betweenness_centrality_df['node'].str.startswith(prefix_soda)]
        centrality_summary_soda_df = centrality_summary_soda_df.merge(betweenness_centrality_df, on="node")
    if k == "ghc_brick.ttl":
        betweenness_centrality_df = betweenness_centrality_df[betweenness_centrality_df['node'].str.startswith(prefix_ghc)]
        centrality_summary_ghc_df = centrality_summary_ghc_df.merge(betweenness_centrality_df, on="node")
    if k == "rice_brick.ttl":
        betweenness_centrality_df = betweenness_centrality_df[betweenness_centrality_df['node'].str.startswith(prefix_rice)]
        centrality_summary_rice_df = centrality_summary_rice_df.merge(betweenness_centrality_df, on="node")
    if k == "ebu3b_brick.ttl":
        betweenness_centrality_df = betweenness_centrality_df[betweenness_centrality_df['node'].str.startswith(prefix_ebu)]
        centrality_summary_ebu_df = centrality_summary_ebu_df.merge(betweenness_centrality_df, on="node")
    if k == "gtc_brick.ttl":
        betweenness_centrality_df = betweenness_centrality_df[betweenness_centrality_df['node'].str.startswith(prefix_gtc)]
        centrality_summary_gtc_df = centrality_summary_gtc_df.merge(betweenness_centrality_df, on="node") 
    # sort
    betweenness_centrality_df = betweenness_centrality_df.sort_values("betweenness_centrality", ascending = False)
    
    # print
    print (k)
    print (betweenness_centrality_df.head(10))
    print ("==================================================")
# Out:
# ebu3b_brick.ttl
#                                                                   node  \
# 198                http://ucsd.edu/building/ontology/ebu3b#EBU3B_AHU_1
# 3650                     http://ucsd.edu/building/ontology/ebu3b#EBU3B
# 655              http://ucsd.edu/building/ontology/ebu3b#EBU3B_Floor_3
# 356              http://ucsd.edu/building/ontology/ebu3b#EBU3B_Floor_2
# 333              http://ucsd.edu/building/ontology/ebu3b#EBU3B_Floor_4
# 1137             http://ucsd.edu/building/ontology/ebu3b#EBU3B_Floor_1
# 632             http://ucsd.edu/building/ontology/ebu3b#EBU3B_Basement
# 100   http://ucsd.edu/building/ontology/ebu3b#EBU3B_AHU_1_Supply_Fan_1
# 1980  http://ucsd.edu/building/ontology/ebu3b#EBU3B_AHU_1_Supply_Fan_2
# 4674  http://ucsd.edu/building/ontology/ebu3b#EBU3B_AHU_1_Supply_Fan_4
#
#       betweenness_centrality
# 198                 0.003237
# 3650                0.000137
# 655                 0.000098
# 356                 0.000097
# 333                 0.000096
# 1137                0.000083
# 632                 0.000038
# 100                 0.000025
# 1980                0.000025
# 4674                0.000025
# ==================================================
# ghc_brick.ttl
#                                                  node  betweenness_centrality
# 303     http://cmu.edu/building/ontology/ghc#AHU-12_I                0.001193
# 864      http://cmu.edu/building/ontology/ghc#AHU-9_I                0.001080
# 226     http://cmu.edu/building/ontology/ghc#AHU-10_I                0.000942
# 592     http://cmu.edu/building/ontology/ghc#AHU-11_I                0.000496
# 577      http://cmu.edu/building/ontology/ghc#AHU-8_I                0.000408
# 129      http://cmu.edu/building/ontology/ghc#AHU-4_I                0.000125
# 301      http://cmu.edu/building/ontology/ghc#AHU-7_I                0.000089
# 342      http://cmu.edu/building/ontology/ghc#AHU-3_I                0.000072
# 333      http://cmu.edu/building/ontology/ghc#AHU-2_I                0.000032
# 897  http://cmu.edu/building/ontology/ghc#AHU-2_IRoom                0.000031
# ==================================================
# gtc_brick.ttl
#                                                                                             node  \
# 86      https://brickschema.org/schema/1.0.2/building_example#building:gtc/radiator_htb/port[so]
# 850                    https://brickschema.org/schema/1.0.2/building_example#building:gtc/damper
# 833          https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/10/port[zn]
# 1366         https://brickschema.org/schema/1.0.2/building_example#building:gtcreturn_fe/port[i]
# 7             https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/1/port[zn]
# 2014  https://brickschema.org/schema/1.0.2/building_example#building:gtcreturn_fe/input_pressure
# 988           https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/0/port[zn]
# 650           https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/3/port[zn]
# 167          https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/11/port[zn]
# 69            https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/8/port[zn]
#
#       betweenness_centrality
# 86                  0.024809
# 850                 0.004256
# 833                 0.004174
# 1366                0.004043
# 7                   0.003981
# 2014                0.003618
# 988                 0.003604
# 650                 0.003388
# 167                 0.003280
# 69                  0.003242
# ==================================================
# rice_brick.ttl
#                                                       node  \
# 289  http://virginia.edu/building/ontology/rice#HVAC_Zone1
# 35   http://virginia.edu/building/ontology/rice#HVAC_Zone2
# 51         http://virginia.edu/building/ontology/rice#VAV2
# 15         http://virginia.edu/building/ontology/rice#VAV1
# 0    http://virginia.edu/building/ontology/rice#HVAC_Zone3
# 75         http://virginia.edu/building/ontology/rice#VAV3
# 158  http://virginia.edu/building/ontology/rice#HVAC_Zone4
# 186        http://virginia.edu/building/ontology/rice#VAV4
# 213     http://virginia.edu/building/ontology/rice#Room322
# 28         http://virginia.edu/building/ontology/rice#VAV5
#
#      betweenness_centrality
# 289                0.000181
# 35                 0.000168
# 51                 0.000155
# 15                 0.000132
# 0                  0.000122
# 75                 0.000119
# 158                0.000098
# 186                0.000095
# 213                0.000087
# 28                 0.000078
# ==================================================
# soda_brick.ttl
#                                                                      node  \
# 486      https://brickschema.org/schema/1.0.2/building_example#building_1
# 29          https://brickschema.org/schema/1.0.2/building_example#floor_3
# 174         https://brickschema.org/schema/1.0.2/building_example#floor_5
# 9           https://brickschema.org/schema/1.0.2/building_example#floor_4
# 133         https://brickschema.org/schema/1.0.2/building_example#floor_6
# 77          https://brickschema.org/schema/1.0.2/building_example#floor_7
# 437         https://brickschema.org/schema/1.0.2/building_example#floor_2
# 148         https://brickschema.org/schema/1.0.2/building_example#floor_1
# 154  https://brickschema.org/schema/1.0.2/building_example#supply_fan_S11
# 44   https://brickschema.org/schema/1.0.2/building_example#supply_fan_S16
#
#      betweenness_centrality
# 486                0.000496
# 29                 0.000213
# 174                0.000200
# 9                  0.000176
# 133                0.000164
# 77                 0.000144
# 437                0.000048
# 148                0.000040
# 154                0.000010
# 44                 0.000010
# ==================================================

# %% [markdown]
# ## 3. Logical centrality

# %% [markdown]
# ###  (1) PageRank centrality

# %%
# pagerank centrality
for k, v in dic.items():
    pagerank_centrality_df = pd.DataFrame(data = nx.pagerank(v).items(), 
                                           columns = ["node", "pagerank_centrality"])
    # filter
    if k == "soda_brick.ttl":
        pagerank_centrality_df = pagerank_centrality_df[pagerank_centrality_df['node'].str.startswith(prefix_soda)]
        centrality_summary_soda_df = centrality_summary_soda_df.merge(pagerank_centrality_df, on="node")
    if k == "ghc_brick.ttl":
        pagerank_centrality_df = pagerank_centrality_df[pagerank_centrality_df['node'].str.startswith(prefix_ghc)]
        centrality_summary_ghc_df = centrality_summary_ghc_df.merge(pagerank_centrality_df, on="node")
    if k == "rice_brick.ttl":
        pagerank_centrality_df = pagerank_centrality_df[pagerank_centrality_df['node'].str.startswith(prefix_rice)]
        centrality_summary_rice_df = centrality_summary_rice_df.merge(pagerank_centrality_df, on="node")
    if k == "ebu3b_brick.ttl":
        pagerank_centrality_df = pagerank_centrality_df[pagerank_centrality_df['node'].str.startswith(prefix_ebu)]
        centrality_summary_ebu_df = centrality_summary_ebu_df.merge(pagerank_centrality_df, on="node")
    if k == "gtc_brick.ttl":
        pagerank_centrality_df = pagerank_centrality_df[pagerank_centrality_df['node'].str.startswith(prefix_gtc)]
        centrality_summary_gtc_df = centrality_summary_gtc_df.merge(pagerank_centrality_df, on="node")
    
    # sort
    pagerank_centrality_df = pagerank_centrality_df.sort_values("pagerank_centrality", ascending = False)
    
    # print
    print (k)
    print (pagerank_centrality_df.head(10))
    print ("==================================================")
# Out:
# ebu3b_brick.ttl
#                                                         node  \
# 3650           http://ucsd.edu/building/ontology/ebu3b#EBU3B
# 655    http://ucsd.edu/building/ontology/ebu3b#EBU3B_Floor_3
# 356    http://ucsd.edu/building/ontology/ebu3b#EBU3B_Floor_2
# 333    http://ucsd.edu/building/ontology/ebu3b#EBU3B_Floor_4
# 1137   http://ucsd.edu/building/ontology/ebu3b#EBU3B_Floor_1
# 198      http://ucsd.edu/building/ontology/ebu3b#EBU3B_AHU_1
# 632   http://ucsd.edu/building/ontology/ebu3b#EBU3B_Basement
# 96      http://ucsd.edu/building/ontology/ebu3b#EBU3B_CRAC_1
# 752     http://ucsd.edu/building/ontology/ebu3b#EBU3B_CRAC_4
# 737     http://ucsd.edu/building/ontology/ebu3b#EBU3B_CRAC_3
#
#       pagerank_centrality
# 3650             0.016258
# 655              0.009092
# 356              0.008933
# 333              0.008851
# 1137             0.007709
# 198              0.005930
# 632              0.003584
# 96               0.001429
# 752              0.001429
# 737              0.001429
# ==================================================
# ghc_brick.ttl
#                                                  node  pagerank_centrality
# 333      http://cmu.edu/building/ontology/ghc#AHU-2_I             0.000718
# 897  http://cmu.edu/building/ontology/ghc#AHU-2_IRoom             0.000718
# 344  http://cmu.edu/building/ontology/ghc#AHU-3_IRoom             0.000673
# 342      http://cmu.edu/building/ontology/ghc#AHU-3_I             0.000673
# 149      http://cmu.edu/building/ontology/ghc#AHU-1_I             0.000670
# 55   http://cmu.edu/building/ontology/ghc#AHU-1_IRoom             0.000670
# 98   http://cmu.edu/building/ontology/ghc#AHU-7_IRoom             0.000667
# 301      http://cmu.edu/building/ontology/ghc#AHU-7_I             0.000667
# 129      http://cmu.edu/building/ontology/ghc#AHU-4_I             0.000655
# 812  http://cmu.edu/building/ontology/ghc#AHU-4_IRoom             0.000655
# ==================================================
# gtc_brick.ttl
#                                                                                                  node  \
# 95            https://brickschema.org/schema/1.0.2/building_example#Celcius_Room_Temperature_Setpoint
# 133                     https://brickschema.org/schema/1.0.2/building_example#Electrical_Energy_Meter
# 145                            https://brickschema.org/schema/1.0.2/building_example#Override_Command
# 59    https://brickschema.org/schema/1.0.2/building_example#building:gtc/electrical/submeter[-A1.0.1]
# 306   https://brickschema.org/schema/1.0.2/building_example#building:gtc/electrical/main_common_meter
# 406                                https://brickschema.org/schema/1.0.2/building_example#building:gtc
# 19    https://brickschema.org/schema/1.0.2/building_example#building:gtc/electrical/submeter[-A1.2.3]
# 1431                      https://brickschema.org/schema/1.0.2/building_example#building:gtc/floors/2
# 34    https://brickschema.org/schema/1.0.2/building_example#building:gtc/electrical/submeter[-A1.2.2]
# 57    https://brickschema.org/schema/1.0.2/building_example#building:gtc/electrical/submeter[-A1.1.1]
#
#       pagerank_centrality
# 95               0.017345
# 133              0.016049
# 145              0.012625
# 59               0.010893
# 306              0.008719
# 406              0.008339
# 19               0.006756
# 1431             0.006607
# 34               0.005999
# 57               0.005791
# ==================================================
# rice_brick.ttl
#                                                                    node  \
# 102                     http://virginia.edu/building/ontology/rice#RICE
# 28                      http://virginia.edu/building/ontology/rice#VAV5
# 4                       http://virginia.edu/building/ontology/rice#VAV6
# 171                     http://virginia.edu/building/ontology/rice#VAV8
# 126                     http://virginia.edu/building/ontology/rice#VAV7
# 505       http://virginia.edu/building/ontology/rice#RMI506_Zone_Temp_7
# 356      http://virginia.edu/building/ontology/rice#RMIC557_Zone_Temp_8
# 204       http://virginia.edu/building/ontology/rice#RMI527_Zone_Temp_8
# 121  http://virginia.edu/building/ontology/rice#RMI527_Zone_Temp_8_Stpt
# 616      http://virginia.edu/building/ontology/rice#RMIC552_Zone_Temp_7
#
#      pagerank_centrality
# 102             0.001758
# 28              0.001153
# 4               0.001153
# 171             0.001153
# 126             0.001153
# 505             0.001050
# 356             0.001035
# 204             0.001016
# 121             0.001016
# 616             0.000998
# ==================================================
# soda_brick.ttl
#                                                                   node  \
# 486   https://brickschema.org/schema/1.0.2/building_example#building_1
# 29       https://brickschema.org/schema/1.0.2/building_example#floor_3
# 174      https://brickschema.org/schema/1.0.2/building_example#floor_5
# 9        https://brickschema.org/schema/1.0.2/building_example#floor_4
# 133      https://brickschema.org/schema/1.0.2/building_example#floor_6
# 77       https://brickschema.org/schema/1.0.2/building_example#floor_7
# 437      https://brickschema.org/schema/1.0.2/building_example#floor_2
# 148      https://brickschema.org/schema/1.0.2/building_example#floor_1
# 769      https://brickschema.org/schema/1.0.2/building_example#floor_8
# 1689     https://brickschema.org/schema/1.0.2/building_example#floor_o
#
#       pagerank_centrality
# 486              0.019537
# 29               0.009589
# 174              0.009102
# 9                0.008063
# 133              0.007441
# 77               0.006540
# 437              0.002448
# 148              0.002102
# 769              0.000458
# 1689             0.000453
# ==================================================

# %% [markdown]
# ### (2) Hit: Authority and Hub scores (inward and outward importance)

# %%
for k, v in dic.items():
    # hits
    hub_scores, auth_scores = nx.hits(v)
    
    # hub score
    hub_centrality_df = pd.DataFrame(data = hub_scores.items(), 
                                           columns = ["node", "hub_centrality"])
    # filter
    if k == "soda_brick.ttl":
        hub_centrality_df = hub_centrality_df[hub_centrality_df['node'].str.startswith(prefix_soda)]
        centrality_summary_soda_df = centrality_summary_soda_df.merge(hub_centrality_df, on="node")
    if k == "ghc_brick.ttl":
        hub_centrality_df = hub_centrality_df[hub_centrality_df['node'].str.startswith(prefix_ghc)]
        centrality_summary_ghc_df = centrality_summary_ghc_df.merge(hub_centrality_df, on="node")
    if k == "rice_brick.ttl":
        hub_centrality_df = hub_centrality_df[hub_centrality_df['node'].str.startswith(prefix_rice)]
        centrality_summary_rice_df = centrality_summary_rice_df.merge(hub_centrality_df, on="node")
    if k == "ebu3b_brick.ttl":
        hub_centrality_df = hub_centrality_df[hub_centrality_df['node'].str.startswith(prefix_ebu)]
        centrality_summary_ebu_df = centrality_summary_ebu_df.merge(hub_centrality_df, on="node")
    if k == "gtc_brick.ttl":
        hub_centrality_df = hub_centrality_df[hub_centrality_df['node'].str.startswith(prefix_gtc)]
        centrality_summary_gtc_df = centrality_summary_gtc_df.merge(hub_centrality_df, on="node")
    
    # sort
    hub_centrality_df = hub_centrality_df.sort_values("hub_centrality", ascending = False)
    
    # print
    print (k)
    print (hub_centrality_df.head(10))
    print ("==================================================")
    
    
    # authority score
    auth_centrality_df = pd.DataFrame(data = auth_scores.items(), 
                                           columns = ["node", "auth_centrality"])
    # filter
    if k == "soda_brick.ttl":
        auth_centrality_df = auth_centrality_df[auth_centrality_df['node'].str.startswith(prefix_soda)]
        centrality_summary_soda_df = centrality_summary_soda_df.merge(auth_centrality_df, on="node")
    if k == "ghc_brick.ttl":
        auth_centrality_df = auth_centrality_df[auth_centrality_df['node'].str.startswith(prefix_ghc)]
        centrality_summary_ghc_df = centrality_summary_ghc_df.merge(auth_centrality_df, on="node")
    if k == "rice_brick.ttl":
        auth_centrality_df = auth_centrality_df[auth_centrality_df['node'].str.startswith(prefix_rice)]
        centrality_summary_rice_df = centrality_summary_rice_df.merge(auth_centrality_df, on="node")
    if k == "ebu3b_brick.ttl":
        auth_centrality_df = auth_centrality_df[auth_centrality_df['node'].str.startswith(prefix_ebu)]
        centrality_summary_ebu_df = centrality_summary_ebu_df.merge(auth_centrality_df, on="node")
    if k == "gtc_brick.ttl":
        auth_centrality_df = auth_centrality_df[auth_centrality_df['node'].str.startswith(prefix_gtc)]
        centrality_summary_gtc_df = centrality_summary_gtc_df.merge(auth_centrality_df, on="node")
    
    # sort
    auth_centrality_df = auth_centrality_df.sort_values("auth_centrality", ascending = False)
    
    # print
    print (k)
    print (auth_centrality_df.head(10))
    print ("==================================================")
# Out:
# ebu3b_brick.ttl
#                                                               node  \
# 3684     http://ucsd.edu/building/ontology/ebu3b#EBU3B_RF2_DO1_CMD
# 3221       http://ucsd.edu/building/ontology/ebu3b#EBU3B_SF3_REF_1
# 1877    http://ucsd.edu/building/ontology/ebu3b#EBU3B_RF2_PID_CTRL
# 2819       http://ucsd.edu/building/ontology/ebu3b#EBU3B_SF1_REF_2
# 3197    http://ucsd.edu/building/ontology/ebu3b#EBU3B_RF1_PID_GAIN
# 1103     http://ucsd.edu/building/ontology/ebu3b#EBU3B_RF2_AO1_CMD
# 4640       http://ucsd.edu/building/ontology/ebu3b#EBU3B_RF3_REF_2
# 5024     http://ucsd.edu/building/ontology/ebu3b#EBU3B_SF1_DO1_CMD
# 1389    http://ucsd.edu/building/ontology/ebu3b#EBU3B_SF4_PID_GAIN
# 1585  http://ucsd.edu/building/ontology/ebu3b#EBU3B_SF3_AI2_ACTUAL
#
#       hub_centrality
# 3684         0.00376
# 3221         0.00376
# 1877         0.00376
# 2819         0.00376
# 3197         0.00376
# 1103         0.00376
# 4640         0.00376
# 5024         0.00376
# 1389         0.00376
# 1585         0.00376
# ==================================================
# ebu3b_brick.ttl
#                                                                       node  \
# 198                    http://ucsd.edu/building/ontology/ebu3b#EBU3B_AHU_1
# 2636  http://ucsd.edu/building/ontology/ebu3b#EBU3B_AHU_1_Supply_Fan_3_VFD
# 895   http://ucsd.edu/building/ontology/ebu3b#EBU3B_AHU_1_Return_Fan_1_VFD
# 930   http://ucsd.edu/building/ontology/ebu3b#EBU3B_AHU_1_Supply_Fan_2_VFD
# 824   http://ucsd.edu/building/ontology/ebu3b#EBU3B_AHU_1_Supply_Fan_1_VFD
# 1012  http://ucsd.edu/building/ontology/ebu3b#EBU3B_AHU_1_Return_Fan_3_VFD
# 1390  http://ucsd.edu/building/ontology/ebu3b#EBU3B_AHU_1_Supply_Fan_4_VFD
# 288   http://ucsd.edu/building/ontology/ebu3b#EBU3B_AHU_1_Return_Fan_4_VFD
# 98    http://ucsd.edu/building/ontology/ebu3b#EBU3B_AHU_1_Return_Fan_2_VFD
# 791                     http://ucsd.edu/building/ontology/ebu3b#EBU3B_HVAC
#
#       auth_centrality
# 198          0.227665
# 2636         0.019886
# 895          0.019886
# 930          0.019886
# 824          0.019886
# 1012         0.019886
# 1390         0.019886
# 288          0.019886
# 98           0.019886
# 791          0.012232
# ==================================================
# ghc_brick.ttl
#                                                                         node  \
# 303                            http://cmu.edu/building/ontology/ghc#AHU-12_I
# 864                             http://cmu.edu/building/ontology/ghc#AHU-9_I
# 226                            http://cmu.edu/building/ontology/ghc#AHU-10_I
# 9338   http://cmu.edu/building/ontology/ghc#SCSC_Gates/AHU-2_I/supply_demand
# 7758   http://cmu.edu/building/ontology/ghc#SCSC_Gates/AHU-7_I/supply_demand
# 8520   http://cmu.edu/building/ontology/ghc#SCSC_Gates/AHU-4_I/supply_demand
# 5753   http://cmu.edu/building/ontology/ghc#SCSC_Gates/AHU-3_I/supply_demand
# 3237   http://cmu.edu/building/ontology/ghc#SCSC_Gates/AHU-1_I/supply_demand
# 7966   http://cmu.edu/building/ontology/ghc#SCSC_Gates/AHU-9_I/supply_demand
# 7280  http://cmu.edu/building/ontology/ghc#SCSC_Gates/AHU-11_I/supply_demand
#
#       hub_centrality
# 303         0.000122
# 864         0.000120
# 226         0.000117
# 9338        0.000110
# 7758        0.000110
# 8520        0.000110
# 5753        0.000110
# 3237        0.000110
# 7966        0.000110
# 7280        0.000110
# ==================================================
# ghc_brick.ttl
#                                                  node  auth_centrality
# 333      http://cmu.edu/building/ontology/ghc#AHU-2_I         0.000992
# 897  http://cmu.edu/building/ontology/ghc#AHU-2_IRoom         0.000992
# 129      http://cmu.edu/building/ontology/ghc#AHU-4_I         0.000937
# 812  http://cmu.edu/building/ontology/ghc#AHU-4_IRoom         0.000937
# 344  http://cmu.edu/building/ontology/ghc#AHU-3_IRoom         0.000937
# 342      http://cmu.edu/building/ontology/ghc#AHU-3_I         0.000937
# 301      http://cmu.edu/building/ontology/ghc#AHU-7_I         0.000937
# 98   http://cmu.edu/building/ontology/ghc#AHU-7_IRoom         0.000937
# 55   http://cmu.edu/building/ontology/ghc#AHU-1_IRoom         0.000919
# 149      http://cmu.edu/building/ontology/ghc#AHU-1_I         0.000919
# ==================================================
# gtc_brick.ttl
#                                                                                              node  \
# 1719   https://brickschema.org/schema/1.0.2/building_example#building:gtc/rooms/3.A.22/lighting/3
# 821    https://brickschema.org/schema/1.0.2/building_example#building:gtc/rooms/3.A.22/lighting/9
# 1513  https://brickschema.org/schema/1.0.2/building_example#building:gtc/rooms/3.A.22/lighting/17
# 111    https://brickschema.org/schema/1.0.2/building_example#building:gtc/rooms/3.A.22/lighting/8
# 116   https://brickschema.org/schema/1.0.2/building_example#building:gtc/rooms/3.A.22/lighting/11
# 1486   https://brickschema.org/schema/1.0.2/building_example#building:gtc/rooms/3.A.22/lighting/7
# 666   https://brickschema.org/schema/1.0.2/building_example#building:gtc/rooms/3.A.22/lighting/19
# 665    https://brickschema.org/schema/1.0.2/building_example#building:gtc/rooms/3.A.22/lighting/1
# 662   https://brickschema.org/schema/1.0.2/building_example#building:gtc/rooms/3.A.22/lighting/13
# 159   https://brickschema.org/schema/1.0.2/building_example#building:gtc/rooms/3.A.22/lighting/12
#
#       hub_centrality
# 1719        0.002911
# 821         0.002911
# 1513        0.002911
# 111         0.002911
# 116         0.002911
# 1486        0.002911
# 666         0.002911
# 665         0.002911
# 662         0.002911
# 159         0.002911
# ==================================================
# gtc_brick.ttl
#                                                                                                 node  \
# 1                        https://brickschema.org/schema/1.0.2/building_example#LEDGO_Lighting_System
# 95           https://brickschema.org/schema/1.0.2/building_example#Celcius_Room_Temperature_Setpoint
# 112             https://brickschema.org/schema/1.0.2/building_example#building:gtc/rooms/3.A.22/room
# 200             https://brickschema.org/schema/1.0.2/building_example#building:gtc/rooms/3.J.29/room
# 76             https://brickschema.org/schema/1.0.2/building_example#building:gtc/rooms/2.A.22A/room
# 190             https://brickschema.org/schema/1.0.2/building_example#building:gtc/rooms/2.H.1A/room
# 59   https://brickschema.org/schema/1.0.2/building_example#building:gtc/electrical/submeter[-A1.0.1]
# 28               https://brickschema.org/schema/1.0.2/building_example#building:gtc/rooms/3.H.1/room
# 51               https://brickschema.org/schema/1.0.2/building_example#building:gtc/rooms/3.A.1/room
# 53   https://brickschema.org/schema/1.0.2/building_example#building:gtc/electrical/submeter[-A1.2.1]
#
#      auth_centrality
# 1           0.085178
# 95          0.050233
# 112         0.036365
# 200         0.029031
# 76          0.027666
# 190         0.027039
# 59          0.026645
# 28          0.022918
# 51          0.021339
# 53          0.020411
# ==================================================
# rice_brick.ttl
#                                                    node  hub_centrality
# 213  http://virginia.edu/building/ontology/rice#Room322        0.007444
# 81   http://virginia.edu/building/ontology/rice#Room306        0.007423
# 17   http://virginia.edu/building/ontology/rice#Room324        0.007376
# 109  http://virginia.edu/building/ontology/rice#Room305        0.007262
# 51      http://virginia.edu/building/ontology/rice#VAV2        0.007238
# 39     http://virginia.edu/building/ontology/rice#Room7        0.007125
# 212  http://virginia.edu/building/ontology/rice#Room308        0.007061
# 259  http://virginia.edu/building/ontology/rice#Room511        0.007007
# 106  http://virginia.edu/building/ontology/rice#Room228        0.006940
# 55    http://virginia.edu/building/ontology/rice#Room32        0.006937
# ==================================================
# rice_brick.ttl
#                                                                                   node  \
# 331       http://virginia.edu/building/ontology/rice#heatCoolModeStatusARoom_305_Area2
# 367          http://virginia.edu/building/ontology/rice#occupancyStatusARoom_305_Area2
# 242  http://virginia.edu/building/ontology/rice#averageSpaceTemperatureARoom_305_Area2
# 548            http://virginia.edu/building/ontology/rice#operatingModeARoom_305_Area2
# 216                      http://virginia.edu/building/ontology/rice#Zone_Temp_2_RMI007
# 235          http://virginia.edu/building/ontology/rice#TEMP2_Space_Temperature_RmI007
# 224       http://virginia.edu/building/ontology/rice#heatCoolModeStatusARoom_306_Area3
# 373              http://virginia.edu/building/ontology/rice#spaceSensorARoom_306_Area3
# 382  http://virginia.edu/building/ontology/rice#averageSpaceTemperatureARoom_306_Area3
# 614          http://virginia.edu/building/ontology/rice#occupancyStatusARoom_306_Area3
#
#      auth_centrality
# 331         0.003688
# 367         0.003688
# 242         0.003688
# 548         0.003688
# 216         0.003641
# 235         0.003641
# 224         0.003617
# 373         0.003617
# 382         0.003617
# 614         0.003617
# ==================================================
# soda_brick.ttl
#                                                                  node  \
# 1305   https://brickschema.org/schema/1.0.2/building_example#vav_R627
# 782    https://brickschema.org/schema/1.0.2/building_example#vav_R787
# 1129   https://brickschema.org/schema/1.0.2/building_example#vav_R339
# 1143   https://brickschema.org/schema/1.0.2/building_example#vav_R779
# 390   https://brickschema.org/schema/1.0.2/building_example#vav_R681A
# 388    https://brickschema.org/schema/1.0.2/building_example#vav_R333
# 1153   https://brickschema.org/schema/1.0.2/building_example#vav_R675
# 380    https://brickschema.org/schema/1.0.2/building_example#vav_R789
# 150    https://brickschema.org/schema/1.0.2/building_example#vav_R765
# 151    https://brickschema.org/schema/1.0.2/building_example#vav_R783
#
#       hub_centrality
# 1305        0.005023
# 782         0.005023
# 1129        0.005023
# 1143        0.005023
# 390         0.005023
# 388         0.005023
# 1153        0.005023
# 380         0.005023
# 150         0.005023
# 151         0.005023
# ==================================================
# soda_brick.ttl
#                                                                                     node  \
# 1223    https://brickschema.org/schema/1.0.2/building_example#flow_sensor_hvac_zone_R633
# 1391    https://brickschema.org/schema/1.0.2/building_example#flow_sensor_hvac_zone_R517
# 910                 https://brickschema.org/schema/1.0.2/building_example#hvac_zone_R633
# 1002                https://brickschema.org/schema/1.0.2/building_example#hvac_zone_R517
# 492   https://brickschema.org/schema/1.0.2/building_example#reheat_sensor_hvac_zone_R633
# 1486  https://brickschema.org/schema/1.0.2/building_example#temp_setpoint_hvac_zone_R517
# 1573    https://brickschema.org/schema/1.0.2/building_example#temp_sensor_hvac_zone_R633
# 108     https://brickschema.org/schema/1.0.2/building_example#temp_sensor_hvac_zone_R517
# 611   https://brickschema.org/schema/1.0.2/building_example#temp_setpoint_hvac_zone_R633
# 758   https://brickschema.org/schema/1.0.2/building_example#reheat_sensor_hvac_zone_R517
#
#       auth_centrality
# 1223         0.000808
# 1391         0.000808
# 910          0.000808
# 1002         0.000808
# 492          0.000808
# 1486         0.000808
# 1573         0.000808
# 108          0.000808
# 611          0.000808
# 758          0.000808
# ==================================================

# %%
print(centrality_summary_rice_df)
# Out:
#                                                                                                 node  \
# 0                                              http://virginia.edu/building/ontology/rice#HVAC_Zone3
# 1                                                 http://virginia.edu/building/ontology/rice#Room210
# 2                                                    http://virginia.edu/building/ontology/rice#VAV6
# 3                                      http://virginia.edu/building/ontology/rice#RMI507_Zone_Temp_6
# 4                                       http://virginia.edu/building/ontology/rice#Zone_Temp_3_RM210
# ..                                                                                               ...
# 690                    http://virginia.edu/building/ontology/rice#heatCoolModeStatusA2nd_Floor_Area1
# 691                        http://virginia.edu/building/ontology/rice#standbyOffsetAAuditorium_Area4
# 692  http://virginia.edu/building/ontology/rice#ventRatioLimitVavV2nd_Floor_Chilled_Beam_Source_VAS2
# 693      http://virginia.edu/building/ontology/rice#ventOptStatusV2nd_Floor_Chilled_Beam_Source_VAS2
# 694                  http://virginia.edu/building/ontology/rice#unoccupiedDifferenceA1st_Floor_Area1
#
#      in_degree_centrality  out_degree_centrality  closeness_centrality  \
# 0                0.001236               0.025958              0.001648
# 1                0.002472               0.004944              0.002825
# 2                0.001236               0.012361              0.001236
# 3                0.002472               0.001236              0.003863
# 4                0.002472               0.001236              0.003863
# ..                    ...                    ...                   ...
# 690              0.000000               0.001236              0.000000
# 691              0.000000               0.001236              0.000000
# 692              0.000000               0.001236              0.000000
# 693              0.000000               0.001236              0.000000
# 694              0.000000               0.001236              0.000000
#
#      betweenness_centrality  pagerank_centrality  hub_centrality  \
# 0              1.223855e-04             0.000645    4.707586e-03
# 1              6.659241e-06             0.000671    6.767958e-03
# 2              4.436476e-05             0.001153    4.718375e-03
# 3              1.343823e-06             0.000922   -2.632956e-18
# 4              9.806303e-07             0.000835   -2.632956e-18
# ..                      ...                  ...             ...
# 690            0.000000e+00             0.000623    3.647615e-21
# 691            0.000000e+00             0.000623    6.745340e-19
# 692            0.000000e+00             0.000623   -5.962911e-21
# 693            0.000000e+00             0.000623    1.024248e-20
# 694            0.000000e+00             0.000623    6.745340e-19
#
#      auth_centrality
# 0       1.101080e-03
# 1       9.273547e-04
# 2       1.504581e-20
# 3       3.069826e-03
# 4       3.394687e-03
# ..               ...
# 690     0.000000e+00
# 691     0.000000e+00
# 692     0.000000e+00
# 693     0.000000e+00
# 694     0.000000e+00
#
# [695 rows x 8 columns]

# %%
# df = pd.DataFrame(columns = ['node','in_degree_centrality','out_degree_centrality','closeness_centrality','betweenness_centrality','pagerank_centrality','hub_centrality','hub_centrality'])

centrality_summary_soda_vav = centrality_summary_soda_df[centrality_summary_soda_df['node'].str.contains("https://brickschema.org/schema/1.0.2/building_example#vav")] 
centrality_summary_ghc_vav = centrality_summary_ghc_df[centrality_summary_ghc_df['node'].str.contains("http://cmu.edu/building/ontology/ghc#VAV_Room")] 
centrality_summary_rice_vav = centrality_summary_rice_df[centrality_summary_rice_df['node'].str.contains("http://virginia.edu/building/ontology/rice#VAV")] 
centrality_summary_ebu_vav = centrality_summary_ebu_df[centrality_summary_ebu_df['node'].str.contains("http://ucsd.edu/building/ontology/ebu3b#EBU3B_VAV") & centrality_summary_ebu_df['node'].str.contains("\d$")] 
centrality_summary_gtc_vav = centrality_summary_gtc_df[centrality_summary_gtc_df['node'].str.contains("https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs") & centrality_summary_gtc_df['node'].str.endswith("vav")]

centrality_summary_gtc_vav
# Out:
#                                                                                 node  \
# 151    https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/9/vav
# 188    https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/4/vav
# 254    https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/5/vav
# 287    https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/6/vav
# 308    https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/1/vav
# 342    https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/8/vav
# 385    https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/3/vav
# 520    https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/7/vav
# 624   https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/10/vav
# 679   https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/11/vav
# 858    https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/2/vav
# 1132   https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/0/vav
#
#       in_degree_centrality  out_degree_centrality  closeness_centrality  \
# 151               0.003126               0.001954              0.021114
# 188               0.003126               0.001954              0.022960
# 254               0.003126               0.001954              0.024237
# 287               0.003126               0.001954              0.018806
# 308               0.003126               0.001954              0.024840
# 342               0.003126               0.001954              0.024069
# 385               0.003126               0.001954              0.023864
# 520               0.003126               0.001954              0.023084
# 624               0.003126               0.001954              0.026513
# 679               0.003126               0.001954              0.024264
# 858               0.003126               0.001954              0.009060
# 1132              0.003126               0.001954              0.024610
#
#       betweenness_centrality  pagerank_centrality  hub_centrality  \
# 151                 0.000686             0.000465        0.000068
# 188                 0.000807             0.000477        0.000069
# 254                 0.000819             0.000472        0.000071
# 287                 0.000617             0.000470        0.000068
# 308                 0.000812             0.000464        0.000067
# 342                 0.000870             0.000473        0.000070
# 385                 0.000887             0.000481        0.000072
# 520                 0.000813             0.000472        0.000069
# 624                 0.000947             0.000471        0.000072
# 679                 0.000874             0.000471        0.000071
# 858                 0.000371             0.000462        0.000065
# 1132                0.000915             0.000476        0.000072
#
#       auth_centrality
# 151          0.000214
# 188          0.000184
# 254          0.000216
# 287          0.000153
# 308          0.000165
# 342          0.000191
# 385          0.000168
# 520          0.000200
# 624          0.000212
# 679          0.000196
# 858          0.000140
# 1132         0.000172

# %%
centrality_summary_soda_vav = centrality_summary_soda_vav.rename(columns={"node":"Node of VAVs"})
centrality_summary_soda_vav = centrality_summary_soda_vav.rename(columns={"in_degree_centrality":"in_degree"})
centrality_summary_soda_vav = centrality_summary_soda_vav.rename(columns={"out_degree_centrality":"out_degree"})
centrality_summary_soda_vav = centrality_summary_soda_vav.rename(columns={"closeness_centrality":"closeness"})
centrality_summary_soda_vav = centrality_summary_soda_vav.rename(columns={"betweenness_centrality":"betweenness"})
centrality_summary_soda_vav = centrality_summary_soda_vav.rename(columns={"pagerank_centrality":"pagerank"})
centrality_summary_soda_vav = centrality_summary_soda_vav.rename(columns={"hub_centrality":"hub"})
centrality_summary_soda_vav = centrality_summary_soda_vav.rename(columns={"auth_centrality":"authority"})

centrality_summary_soda_vav['total'] = centrality_summary_soda_vav[['in_degree','out_degree','closeness', 'betweenness', 'pagerank', 'hub', 'authority']].mean(axis=1)

centrality_summary_soda_vav = centrality_summary_soda_vav.sort_values(by='total',ascending=False)

centrality_summary_soda_vav
# Out:
#                                                          Node of VAVs  \
# 830    https://brickschema.org/schema/1.0.2/building_example#vav_R369
# 507    https://brickschema.org/schema/1.0.2/building_example#vav_R441
# 63     https://brickschema.org/schema/1.0.2/building_example#vav_R449
# 860    https://brickschema.org/schema/1.0.2/building_example#vav_R445
# 90     https://brickschema.org/schema/1.0.2/building_example#vav_R443
# ...                                                               ...
# 500   https://brickschema.org/schema/1.0.2/building_example#vav_R500A
# 387    https://brickschema.org/schema/1.0.2/building_example#vav_R452
# 424    https://brickschema.org/schema/1.0.2/building_example#vav_R181
# 406    https://brickschema.org/schema/1.0.2/building_example#vav_R179
# 1013   https://brickschema.org/schema/1.0.2/building_example#vav_R183
#
#       in_degree  out_degree  closeness  betweenness  pagerank       hub  \
# 830    0.001151    0.004028   0.001151     0.000004  0.000282  0.005023
# 507    0.000575    0.004028   0.000575     0.000002  0.000280  0.005023
# 63     0.000575    0.004028   0.000575     0.000002  0.000280  0.005023
# 860    0.000575    0.004028   0.000575     0.000002  0.000280  0.005023
# 90     0.000575    0.004028   0.000575     0.000002  0.000280  0.005023
# ...         ...         ...        ...          ...       ...       ...
# 500    0.000575    0.001726   0.000575     0.000001  0.000279  0.002967
# 387    0.000575    0.001726   0.000575     0.000001  0.000279  0.002967
# 424    0.000000    0.002301   0.000000     0.000000  0.000277  0.002976
# 406    0.000000    0.002301   0.000000     0.000000  0.000277  0.002976
# 1013   0.000000    0.002301   0.000000     0.000000  0.000277  0.002976
#
#          authority     total
# 830   4.561542e-18  0.001663
# 507  -3.774555e-19  0.001498
# 63   -3.774555e-19  0.001498
# 860  -3.774555e-19  0.001498
# 90   -3.774555e-19  0.001498
# ...            ...       ...
# 500   4.938997e-18  0.000875
# 387   4.938997e-18  0.000875
# 424   0.000000e+00  0.000793
# 406   0.000000e+00  0.000793
# 1013  0.000000e+00  0.000793
#
# [243 rows x 9 columns]

# %%
plt.style.use('ggplot')

plt.figure(figsize=(14, 7), dpi=80)
centrality_summary_soda_vav.plot(x="Node of VAVs", y=["in_degree", "out_degree", "closeness", "betweenness", "pagerank", "hub", "authority"], \
                                 kind="bar", figsize=(15, 6), stacked=True)
plt.xticks([])
plt.legend(loc='upper right')

plt.savefig("soda.png", format="png", bbox_inches = 'tight', pad_inches = 0)
plt.show()

# %%
centrality_summary_ghc_vav = centrality_summary_ghc_vav.rename(columns={"node":"Node of VAVs"})
centrality_summary_ghc_vav = centrality_summary_ghc_vav.rename(columns={"in_degree_centrality":"in_degree"})
centrality_summary_ghc_vav = centrality_summary_ghc_vav.rename(columns={"out_degree_centrality":"out_degree"})
centrality_summary_ghc_vav = centrality_summary_ghc_vav.rename(columns={"closeness_centrality":"closeness"})
centrality_summary_ghc_vav = centrality_summary_ghc_vav.rename(columns={"betweenness_centrality":"betweenness"})
centrality_summary_ghc_vav = centrality_summary_ghc_vav.rename(columns={"pagerank_centrality":"pagerank"})
centrality_summary_ghc_vav = centrality_summary_ghc_vav.rename(columns={"hub_centrality":"hub"})
centrality_summary_ghc_vav = centrality_summary_ghc_vav.rename(columns={"auth_centrality":"authority"})

centrality_summary_ghc_vav['total'] = centrality_summary_ghc_vav[['in_degree','out_degree','closeness', 'betweenness', 'pagerank', 'hub', 'authority']].mean(axis=1)

centrality_summary_ghc_vav = centrality_summary_ghc_vav.sort_values(by='total',ascending=False)

centrality_summary_ghc_vav
# Out:
#                                                          Node of VAVs  \
# 1717     http://cmu.edu/building/ontology/ghc#VAV_Room_4215_Classroom
# 3083  http://cmu.edu/building/ontology/ghc#VAV_Room_9022_Project_Room
# 776   http://cmu.edu/building/ontology/ghc#VAV_Room_8014_Open_Project
# 1842  http://cmu.edu/building/ontology/ghc#VAV_Room_9001_Reading_Room
# 4363  http://cmu.edu/building/ontology/ghc#VAV_Room_8025_Open_Project
# ...                                                               ...
# 4134    http://cmu.edu/building/ontology/ghc#VAV_Room_9217_OfficeZone
# 6867    http://cmu.edu/building/ontology/ghc#VAV_Room_9215_OfficeZone
# 2052    http://cmu.edu/building/ontology/ghc#VAV_Room_9213_OfficeZone
# 8038    http://cmu.edu/building/ontology/ghc#VAV_Room_9211_OfficeZone
# 925    http://cmu.edu/building/ontology/ghc#VAV_Room_9214_StorageZone
#
#       in_degree  out_degree  closeness   betweenness  pagerank       hub  \
# 1717   0.002330    0.002431   0.004549  1.869023e-05  0.000312  0.000104
# 3083   0.002330    0.002431   0.004451  1.640115e-05  0.000306  0.000104
# 776    0.002330    0.002431   0.004451  1.631625e-05  0.000304  0.000104
# 1842   0.002330    0.002431   0.004451  1.631625e-05  0.000304  0.000104
# 4363   0.002330    0.002431   0.004451  1.631625e-05  0.000304  0.000104
# ...         ...         ...        ...           ...       ...       ...
# 4134   0.000203    0.000405   0.000965  1.846793e-07  0.000057  0.000104
# 6867   0.000203    0.000405   0.000965  1.846793e-07  0.000057  0.000104
# 2052   0.000203    0.000405   0.000965  1.846793e-07  0.000057  0.000104
# 8038   0.000203    0.000405   0.000965  1.846793e-07  0.000057  0.000104
# 925    0.000203    0.000405   0.000915  1.744193e-07  0.000057  0.000104
#
#       authority     total
# 1717   0.000418  0.001452
# 3083   0.000420  0.001437
# 776    0.000422  0.001437
# 1842   0.000422  0.001437
# 4363   0.000422  0.001437
# ...         ...       ...
# 4134   0.000036  0.000253
# 6867   0.000036  0.000253
# 2052   0.000036  0.000253
# 8038   0.000036  0.000253
# 925    0.000036  0.000246
#
# [1253 rows x 9 columns]

# %%
plt.style.use('ggplot')

plt.figure(figsize=(14, 7), dpi=80)
centrality_summary_ghc_vav.plot(x="Node of VAVs", y=["in_degree", "out_degree", "closeness", "betweenness", "pagerank", "hub", "authority"], \
                                 kind="bar", figsize=(12, 6), stacked=True)
plt.xticks([])
plt.legend(loc='upper right')

plt.savefig("ghc.png", format="png", bbox_inches = 'tight', pad_inches = 0)
plt.show()

# %%
centrality_summary_rice_vav = centrality_summary_rice_vav.rename(columns={"node":"Node of VAVs"})
centrality_summary_rice_vav = centrality_summary_rice_vav.rename(columns={"in_degree_centrality":"in_degree"})
centrality_summary_rice_vav = centrality_summary_rice_vav.rename(columns={"out_degree_centrality":"out_degree"})
centrality_summary_rice_vav = centrality_summary_rice_vav.rename(columns={"closeness_centrality":"closeness"})
centrality_summary_rice_vav = centrality_summary_rice_vav.rename(columns={"betweenness_centrality":"betweenness"})
centrality_summary_rice_vav = centrality_summary_rice_vav.rename(columns={"pagerank_centrality":"pagerank"})
centrality_summary_rice_vav = centrality_summary_rice_vav.rename(columns={"hub_centrality":"hub"})
centrality_summary_rice_vav = centrality_summary_rice_vav.rename(columns={"auth_centrality":"authority"})

centrality_summary_rice_vav['total'] = centrality_summary_rice_vav[['in_degree','out_degree','closeness', 'betweenness', 'pagerank', 'hub', 'authority']].mean(axis=1)

centrality_summary_rice_vav = centrality_summary_rice_vav.sort_values(by='total',ascending=False)

centrality_summary_rice_vav
# Out:
#                                                           Node of VAVs  \
# 40                     http://virginia.edu/building/ontology/rice#VAV2
# 61                     http://virginia.edu/building/ontology/rice#VAV3
# 10                     http://virginia.edu/building/ontology/rice#VAV1
# 149                    http://virginia.edu/building/ontology/rice#VAV4
# 20                     http://virginia.edu/building/ontology/rice#VAV5
# 2                      http://virginia.edu/building/ontology/rice#VAV6
# 137                    http://virginia.edu/building/ontology/rice#VAV8
# 102                    http://virginia.edu/building/ontology/rice#VAV7
# 403      http://virginia.edu/building/ontology/rice#VAV_HW_Supply_Temp
# 463  http://virginia.edu/building/ontology/rice#VAV_211_HW_Return_Temp
# 553      http://virginia.edu/building/ontology/rice#VAV_HW_Return_Temp
# 579   http://virginia.edu/building/ontology/rice#VAV_26_HW_Supply_Temp
# 597  http://virginia.edu/building/ontology/rice#VAV_211_HW_Supply_Temp
# 686   http://virginia.edu/building/ontology/rice#VAV_26_HW_Return_Temp
#
#      in_degree  out_degree  closeness  betweenness  pagerank           hub  \
# 40    0.001236    0.048208   0.001236     0.000155  0.000800  7.238167e-03
# 61    0.001236    0.038319   0.001236     0.000119  0.000800  6.498115e-03
# 10    0.001236    0.030902   0.001236     0.000132  0.000800  5.933497e-03
# 149   0.001236    0.028430   0.001236     0.000095  0.000800  5.789286e-03
# 20    0.001236    0.023486   0.001236     0.000078  0.001153  5.448547e-03
# 2     0.001236    0.012361   0.001236     0.000044  0.001153  4.718375e-03
# 137   0.001236    0.007417   0.001236     0.000020  0.001153  4.420093e-03
# 102   0.001236    0.006180   0.001236     0.000020  0.001153  4.348534e-03
# 403   0.000000    0.001236   0.000000     0.000000  0.000623 -9.860982e-21
# 463   0.000000    0.001236   0.000000     0.000000  0.000623 -5.909147e-21
# 553   0.000000    0.001236   0.000000     0.000000  0.000623 -5.909147e-21
# 579   0.000000    0.001236   0.000000     0.000000  0.000623 -9.860982e-21
# 597   0.000000    0.001236   0.000000     0.000000  0.000623 -9.860982e-21
# 686   0.000000    0.001236   0.000000     0.000000  0.000623 -5.909147e-21
#
#         authority     total
# 40   1.644841e-06  0.008411
# 61   1.644841e-06  0.006887
# 10   1.644841e-06  0.005749
# 149  1.644841e-06  0.005370
# 20  -4.340363e-20  0.004663
# 2    1.504581e-20  0.002964
# 137 -2.335148e-21  0.002212
# 102  4.617204e-20  0.002025
# 403  0.000000e+00  0.000266
# 463  0.000000e+00  0.000266
# 553  0.000000e+00  0.000266
# 579  0.000000e+00  0.000266
# 597  0.000000e+00  0.000266
# 686  0.000000e+00  0.000266

# %%
plt.style.use('ggplot')

plt.figure(figsize=(14, 7), dpi=80)
centrality_summary_rice_vav.plot(x="Node of VAVs", y=["in_degree", "out_degree", "closeness", "betweenness", "pagerank", "hub", "authority"], \
                                 kind="bar", figsize=(12, 6), stacked=True)
plt.xticks([])
plt.legend(loc='upper right')

plt.savefig("rice.png", format="png", bbox_inches = 'tight', pad_inches = 0)
plt.show()

# %%
centrality_summary_ebu_vav = centrality_summary_ebu_vav.rename(columns={"node":"Node of VAVs"})
centrality_summary_ebu_vav = centrality_summary_ebu_vav.rename(columns={"in_degree_centrality":"in_degree"})
centrality_summary_ebu_vav = centrality_summary_ebu_vav.rename(columns={"out_degree_centrality":"out_degree"})
centrality_summary_ebu_vav = centrality_summary_ebu_vav.rename(columns={"closeness_centrality":"closeness"})
centrality_summary_ebu_vav = centrality_summary_ebu_vav.rename(columns={"betweenness_centrality":"betweenness"})
centrality_summary_ebu_vav = centrality_summary_ebu_vav.rename(columns={"pagerank_centrality":"pagerank"})
centrality_summary_ebu_vav = centrality_summary_ebu_vav.rename(columns={"hub_centrality":"hub"})
centrality_summary_ebu_vav = centrality_summary_ebu_vav.rename(columns={"auth_centrality":"authority"})

centrality_summary_ebu_vav['total'] = centrality_summary_ebu_vav[['in_degree','out_degree','closeness', 'betweenness', 'pagerank', 'hub', 'authority']].mean(axis=1)

centrality_summary_ebu_vav = centrality_summary_ebu_vav.sort_values(by='total',ascending=False)

centrality_summary_ebu_vav
# Out:
#                                                    Node of VAVs  in_degree  \
# 1739  http://ucsd.edu/building/ontology/ebu3b#EBU3B_VAV_Rm_B210   0.004236
# 384   http://ucsd.edu/building/ontology/ebu3b#EBU3B_VAV_Rm_B260   0.004079
# 430   http://ucsd.edu/building/ontology/ebu3b#EBU3B_VAV_Rm_B230   0.004079
# 476   http://ucsd.edu/building/ontology/ebu3b#EBU3B_VAV_Rm_B270   0.004079
# 207   http://ucsd.edu/building/ontology/ebu3b#EBU3B_VAV_Rm_B220   0.004079
# ...                                                         ...        ...
# 231   http://ucsd.edu/building/ontology/ebu3b#EBU3B_VAV_Rm_4207   0.002353
# 2109  http://ucsd.edu/building/ontology/ebu3b#EBU3B_VAV_Rm_3207   0.002353
# 589   http://ucsd.edu/building/ontology/ebu3b#EBU3B_VAV_Rm_2209   0.002353
# 872   http://ucsd.edu/building/ontology/ebu3b#EBU3B_VAV_Rm_2207   0.002353
# 3774  http://ucsd.edu/building/ontology/ebu3b#EBU3B_VAV_Rm_3218   0.000314
#
#       out_degree  closeness  betweenness  pagerank           hub  authority  \
# 1739    0.000314   0.023181     0.000011  0.000755  6.545138e-07   0.000752
# 384     0.000314   0.023063     0.000011  0.000729  6.519452e-07   0.000730
# 430     0.000314   0.023063     0.000011  0.000729  6.519452e-07   0.000730
# 476     0.000314   0.023063     0.000011  0.000729  6.519452e-07   0.000730
# 207     0.000314   0.023063     0.000011  0.000729  6.519452e-07   0.000730
# ...          ...        ...          ...       ...           ...        ...
# 231     0.000314   0.021783     0.000009  0.000448  5.979309e-07   0.000649
# 2109    0.000314   0.021783     0.000009  0.000448  5.979309e-07   0.000649
# 589     0.000314   0.021783     0.000009  0.000448  5.979309e-07   0.000649
# 872     0.000314   0.021783     0.000009  0.000448  5.979309e-07   0.000649
# 3774    0.000000   0.000314     0.000000  0.000110  0.000000e+00   0.000012
#
#          total
# 1739  0.004178
# 384   0.004132
# 430   0.004132
# 476   0.004132
# 207   0.004132
# ...        ...
# 231   0.003651
# 2109  0.003651
# 589   0.003651
# 872   0.003651
# 3774  0.000107
#
# [219 rows x 9 columns]

# %%
plt.style.use('ggplot')

plt.figure(figsize=(14, 7), dpi=80)
centrality_summary_ebu_vav.plot(x="Node of VAVs", y=["in_degree", "out_degree", "closeness", "betweenness", "pagerank", "hub", "authority"], \
                                 kind="bar", figsize=(12, 6), stacked=True)
plt.xticks([])
plt.legend(loc='upper right')

plt.savefig("ebu.png", format="png", bbox_inches = 'tight', pad_inches = 0)
plt.show()

# %%
centrality_summary_gtc_vav = centrality_summary_gtc_vav.rename(columns={"node":"Node of VAVs"})
centrality_summary_gtc_vav = centrality_summary_gtc_vav.rename(columns={"in_degree_centrality":"in_degree"})
centrality_summary_gtc_vav = centrality_summary_gtc_vav.rename(columns={"out_degree_centrality":"out_degree"})
centrality_summary_gtc_vav = centrality_summary_gtc_vav.rename(columns={"closeness_centrality":"closeness"})
centrality_summary_gtc_vav = centrality_summary_gtc_vav.rename(columns={"betweenness_centrality":"betweenness"})
centrality_summary_gtc_vav = centrality_summary_gtc_vav.rename(columns={"pagerank_centrality":"pagerank"})
centrality_summary_gtc_vav = centrality_summary_gtc_vav.rename(columns={"hub_centrality":"hub"})
centrality_summary_gtc_vav = centrality_summary_gtc_vav.rename(columns={"auth_centrality":"authority"})

centrality_summary_gtc_vav['total'] = centrality_summary_gtc_vav[['in_degree','out_degree','closeness', 'betweenness', 'pagerank', 'hub', 'authority']].mean(axis=1)

centrality_summary_gtc_vav = centrality_summary_gtc_vav.sort_values(by='total',ascending=False)

centrality_summary_gtc_vav
# Out:
#                                                                         Node of VAVs  \
# 624   https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/10/vav
# 308    https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/1/vav
# 1132   https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/0/vav
# 679   https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/11/vav
# 254    https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/5/vav
# 342    https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/8/vav
# 385    https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/3/vav
# 520    https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/7/vav
# 188    https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/4/vav
# 151    https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/9/vav
# 287    https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/6/vav
# 858    https://brickschema.org/schema/1.0.2/building_example#building:gtc/vavs/2/vav
#
#       in_degree  out_degree  closeness  betweenness  pagerank       hub  \
# 624    0.003126    0.001954   0.026513     0.000947  0.000471  0.000072
# 308    0.003126    0.001954   0.024840     0.000812  0.000464  0.000067
# 1132   0.003126    0.001954   0.024610     0.000915  0.000476  0.000072
# 679    0.003126    0.001954   0.024264     0.000874  0.000471  0.000071
# 254    0.003126    0.001954   0.024237     0.000819  0.000472  0.000071
# 342    0.003126    0.001954   0.024069     0.000870  0.000473  0.000070
# 385    0.003126    0.001954   0.023864     0.000887  0.000481  0.000072
# 520    0.003126    0.001954   0.023084     0.000813  0.000472  0.000069
# 188    0.003126    0.001954   0.022960     0.000807  0.000477  0.000069
# 151    0.003126    0.001954   0.021114     0.000686  0.000465  0.000068
# 287    0.003126    0.001954   0.018806     0.000617  0.000470  0.000068
# 858    0.003126    0.001954   0.009060     0.000371  0.000462  0.000065
#
#       authority     total
# 624    0.000212  0.004756
# 308    0.000165  0.004490
# 1132   0.000172  0.004475
# 679    0.000196  0.004422
# 254    0.000216  0.004414
# 342    0.000191  0.004393
# 385    0.000168  0.004365
# 520    0.000200  0.004245
# 188    0.000184  0.004225
# 151    0.000214  0.003947
# 287    0.000153  0.003599
# 858    0.000140  0.002168

# %%
plt.style.use('ggplot')

plt.figure(figsize=(14, 7), dpi=80)
centrality_summary_gtc_vav.plot(x="Node of VAVs", y=["in_degree", "out_degree", "closeness", "betweenness", "pagerank", "hub", "authority"], \
                                 kind="bar", figsize=(8, 6), stacked=True)
plt.xticks([])
plt.legend(loc='upper right')

plt.savefig("gtc.png", format="png", bbox_inches = 'tight', pad_inches = 0)
plt.show()

# %%
from openpyxl import Workbook

with pd.ExcelWriter('pandas_to_excel.xlsx') as writer:
    centrality_summary_soda_vav.to_excel(writer, sheet_name='sheet1')
